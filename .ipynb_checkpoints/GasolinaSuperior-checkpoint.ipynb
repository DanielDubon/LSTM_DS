# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa as tsa
import statsmodels as sm
from datetime import datetime
import os
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.metrics import mean_squared_error
# Out:
# 2025-07-25 19:12:57.650238: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-25 19:12:57.769103: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753492377.827912  103048 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753492377.841087  103048 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-25 19:12:57.941731: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
sup_imp = pd.read_csv('./data/importacion.csv', parse_dates=['Fecha'], dayfirst=True)
sup_imp.set_index('Fecha', inplace=True)
sup_imp_h = sup_imp['Gasolina superior']

sup_imp_h.head()
# Out:
# Fecha
# 2001-01-01    373963.96
# 2001-01-02    243091.07
# 2001-01-03    312084.38
# 2001-01-04    285054.89
# 2001-01-05    300913.67
# Name: Gasolina superior, dtype: float64

# %%
plt.plot(sup_imp_h)
plt.gca().set(title="Imp Gasolina Superior", ylabel="cantidad" , xlabel="año")
plt.show()

# %%
# Se calcula la media móvil y la desviación estandar móvil de los últimos 12 meses.
mediaMovil = sup_imp_h.rolling(window=12).mean()
deMovil = sup_imp_h.rolling(window=12).std()
# Se grafican los resultados.
original = plt.plot(sup_imp_h, color="blue", label="Original")
media = plt.plot(mediaMovil, color='red', label = 'Media Movil')
ds = plt.plot(deMovil,color='black', label = 'Desviación Estándar Móvil')
plt.legend(loc = 'best')
plt.title('Media y desviación estándar móvil')
plt.show(block=False)

# %%
descomposicion = seasonal_decompose(sup_imp_h, period= 12)
descomposicion.plot()

# %%
print('Resultados del Test de Dickey Fuller')
dfTest = adfuller(sup_imp_h, autolag='AIC')
salidaDf = pd.Series(dfTest[0:4], index=['Estadístico de prueba','p-value','# de retardos usados','# de observaciones usadas'])
for key,value in dfTest[4].items():
        salidaDf['Critical Value (%s)'%key] = value
print(salidaDf)
# Out:
# Resultados del Test de Dickey Fuller
# Estadístico de prueba         -1.601987
# p-value                        0.482595
# # de retardos usados           9.000000
# # de observaciones usadas    278.000000
# Critical Value (1%)           -3.454094
# Critical Value (5%)           -2.871993
# Critical Value (10%)          -2.572340
# dtype: float64

# %% [markdown]
# p-values es mayor a 0.05

# %%
print('Resultados del Test de Dickey Fuller para una diferenciación de la serie')
sup_imp_h_diff = sup_imp_h.diff()
sup_imp_h_diff.fillna(0,inplace=True)
dfTest = adfuller(sup_imp_h_diff)
salidaDf = pd.Series(dfTest[0:4], index=['Estadístico de prueba','p-value','# de retardos usados','# de observaciones usadas'])
for key,value in dfTest[4].items():
        salidaDf['Critical Value (%s)'%key] = value
print(salidaDf)
# Out:
# Resultados del Test de Dickey Fuller para una diferenciación de la serie
# Estadístico de prueba       -7.800177e+00
# p-value                      7.529848e-12
# # de retardos usados         1.100000e+01
# # de observaciones usadas    2.760000e+02
# Critical Value (1%)         -3.454267e+00
# Critical Value (5%)         -2.872070e+00
# Critical Value (10%)        -2.572381e+00
# dtype: float64

# %%
plt.plot(sup_imp_h_diff)

# %%
scaler = StandardScaler()
sup_imp_h_diff_scaled = scaler.fit_transform(sup_imp_h_diff.values.reshape(-1, 1))
sup_imp_h_diff_scaled[1:7]
# Out:
# array([[-0.84051577],
#        [ 0.43027508],
#        [-0.18025785],
#        [ 0.09243469],
#        [ 0.19699376],
#        [-0.88675546]])

# %% [markdown]
# # Fase de Entrenamiento

# %%
total_len = len(sup_imp_h_diff_scaled)

# Definir proporciones
train_prop = 0.6
val_prop = 0.2
test_prop = 0.2 

# Calcular índices
train_end = int(train_prop * total_len)
val_end = train_end + int(val_prop * total_len)

# Separar sin solapamientos
train = sup_imp_h_diff_scaled[:train_end]
validation = sup_imp_h_diff_scaled[train_end:val_end]
test = sup_imp_h_diff_scaled[val_end:]

# Si hace falta, redimensionar (por ejemplo para un LSTM univariante)
train = train.reshape(-1, 1)
validation = validation.reshape(-1, 1)
test = test.reshape(-1, 1)

# Verificar tamaños
print(f"Total registros: {total_len}")
print(f"Train: {len(train)} | Validation: {len(validation)} | Test: {len(test)}")
# Out:
# Total registros: 288
# Train: 172 | Validation: 57 | Test: 59

# %%
train, type(train)
# Out:
# (array([[-0.00839873],
#         [-0.84051577],
#         [ 0.43027508],
#         [-0.18025785],
#         [ 0.09243469],
#         [ 0.19699376],
#         [-0.88675546],
#         [ 0.456268  ],
#         [ 0.24774682],
#         [-0.02961474],
#         [-0.31654349],
#         [ 0.12198815],
#         [-0.04442466],
#         [ 0.59040934],
#         [-0.76734717],
#         [ 0.39829577],
#         [ 0.32893891],
#         [-0.72807519],
#         [ 1.1279377 ],
#         [-0.83854206],
#         [ 0.19998117],
#         [ 0.12513508],
#         [-0.39540212],
#         [ 0.94208373],
#         [-0.10690206],
#         [ 0.11027309],
#         [-0.5202166 ],
#         [-0.18584341],
#         [ 0.77735496],
#         [-0.5586327 ],
#         [ 0.17240607],
#         [-0.69863262],
#         [ 0.6644721 ],
#         [-0.88565492],
#         [ 0.84189738],
#         [-0.6262373 ],
#         [ 0.44592695],
#         [-0.55738656],
#         [ 1.29496299],
#         [-0.46272333],
#         [-0.42405417],
#         [-0.25519219],
#         [-0.39960224],
#         [ 1.16702684],
#         [-0.09759059],
#         [-0.34960554],
#         [ 0.42284443],
#         [-0.01832377],
#         [-1.12287794],
#         [ 0.30183349],
#         [ 0.7879504 ],
#         [ 0.64168988],
#         [-0.99732584],
#         [ 1.00117106],
#         [-1.11464762],
#         [ 1.28363775],
#         [-2.3808626 ],
#         [ 2.12409708],
#         [-1.15407963],
#         [ 0.0686576 ],
#         [ 2.22367412],
#         [-2.86762041],
#         [ 0.91922845],
#         [ 0.0757552 ],
#         [-0.70319902],
#         [ 0.51291169],
#         [-0.12325143],
#         [-0.40657705],
#         [ 1.34142522],
#         [-1.53511985],
#         [ 0.90136862],
#         [-0.22113426],
#         [ 0.80925549],
#         [-0.78330468],
#         [ 0.88151156],
#         [-2.15986699],
#         [ 2.16703857],
#         [-0.66997179],
#         [ 0.0529162 ],
#         [ 0.31370458],
#         [-1.06207751],
#         [ 0.24756326],
#         [ 0.85741599],
#         [ 0.18467753],
#         [-2.15829111],
#         [ 2.15562705],
#         [-0.89490045],
#         [ 1.03780305],
#         [-0.93225969],
#         [-0.97202424],
#         [ 0.69832224],
#         [-0.915513  ],
#         [ 1.14474302],
#         [-0.6027759 ],
#         [ 0.35149332],
#         [ 0.45310778],
#         [-0.49574812],
#         [ 0.88505823],
#         [ 0.65164797],
#         [-1.77829065],
#         [-0.05015423],
#         [ 1.56613077],
#         [-1.61171712],
#         [ 0.87763477],
#         [-0.99262649],
#         [ 2.01221214],
#         [-2.02817992],
#         [ 0.71361863],
#         [-0.7489167 ],
#         [ 1.09476833],
#         [-1.2081265 ],
#         [ 1.6398594 ],
#         [-0.85573605],
#         [ 0.21147713],
#         [-0.05749942],
#         [ 0.11320664],
#         [-0.99124771],
#         [ 1.08940773],
#         [-1.61531834],
#         [ 2.60576579],
#         [-1.66288855],
#         [ 0.28262878],
#         [ 0.04342569],
#         [-0.57154902],
#         [ 0.47284423],
#         [-0.50709326],
#         [ 0.08754548],
#         [-0.63741274],
#         [ 0.40512964],
#         [ 0.09175474],
#         [ 0.61888387],
#         [ 0.53022134],
#         [-0.64598195],
#         [-0.40104783],
#         [-0.12750475],
#         [ 0.2811594 ],
#         [-0.13028456],
#         [ 1.07152686],
#         [-1.78151299],
#         [ 0.56255562],
#         [ 0.06587843],
#         [ 1.43558042],
#         [-1.53612025],
#         [ 0.36807476],
#         [ 0.08631008],
#         [ 0.22405283],
#         [-0.26596853],
#         [-0.00658658],
#         [ 0.64090451],
#         [-1.58740644],
#         [ 1.27619471],
#         [-0.89224654],
#         [ 0.15842284],
#         [-0.01066848],
#         [ 0.77419105],
#         [-0.88093611],
#         [ 0.61830324],
#         [-0.01882238],
#         [ 0.79812004],
#         [-1.99388083],
#         [ 1.8546679 ],
#         [-1.01754958],
#         [ 0.96949275],
#         [-1.02469424],
#         [ 0.93848301],
#         [-1.07603181],
#         [ 0.97046219],
#         [ 0.30669606],
#         [-0.71484821],
#         [ 1.21455519],
#         [-0.27183677],
#         [-0.15670107]]),
#  numpy.ndarray)

# %%
from operator import concat


def supervisada(serie,retrasos = 1):
    serie_x = []
    serie_y = []
    for i in range(len(serie)-retrasos):
        valor = serie[i:(i+retrasos),0]
        valor_sig = serie[i+retrasos,0]
        serie_x.append(valor)
        serie_y.append(valor_sig)
    return np.array(serie_x), np.array(serie_y)

x_train,y_train = supervisada(train)
x_val,y_val = supervisada(validation)
x_test,y_test = supervisada(test)

# %%
x_train
# Out:
# array([[-0.00839873],
#        [-0.84051577],
#        [ 0.43027508],
#        [-0.18025785],
#        [ 0.09243469],
#        [ 0.19699376],
#        [-0.88675546],
#        [ 0.456268  ],
#        [ 0.24774682],
#        [-0.02961474],
#        [-0.31654349],
#        [ 0.12198815],
#        [-0.04442466],
#        [ 0.59040934],
#        [-0.76734717],
#        [ 0.39829577],
#        [ 0.32893891],
#        [-0.72807519],
#        [ 1.1279377 ],
#        [-0.83854206],
#        [ 0.19998117],
#        [ 0.12513508],
#        [-0.39540212],
#        [ 0.94208373],
#        [-0.10690206],
#        [ 0.11027309],
#        [-0.5202166 ],
#        [-0.18584341],
#        [ 0.77735496],
#        [-0.5586327 ],
#        [ 0.17240607],
#        [-0.69863262],
#        [ 0.6644721 ],
#        [-0.88565492],
#        [ 0.84189738],
#        [-0.6262373 ],
#        [ 0.44592695],
#        [-0.55738656],
#        [ 1.29496299],
#        [-0.46272333],
#        [-0.42405417],
#        [-0.25519219],
#        [-0.39960224],
#        [ 1.16702684],
#        [-0.09759059],
#        [-0.34960554],
#        [ 0.42284443],
#        [-0.01832377],
#        [-1.12287794],
#        [ 0.30183349],
#        [ 0.7879504 ],
#        [ 0.64168988],
#        [-0.99732584],
#        [ 1.00117106],
#        [-1.11464762],
#        [ 1.28363775],
#        [-2.3808626 ],
#        [ 2.12409708],
#        [-1.15407963],
#        [ 0.0686576 ],
#        [ 2.22367412],
#        [-2.86762041],
#        [ 0.91922845],
#        [ 0.0757552 ],
#        [-0.70319902],
#        [ 0.51291169],
#        [-0.12325143],
#        [-0.40657705],
#        [ 1.34142522],
#        [-1.53511985],
#        [ 0.90136862],
#        [-0.22113426],
#        [ 0.80925549],
#        [-0.78330468],
#        [ 0.88151156],
#        [-2.15986699],
#        [ 2.16703857],
#        [-0.66997179],
#        [ 0.0529162 ],
#        [ 0.31370458],
#        [-1.06207751],
#        [ 0.24756326],
#        [ 0.85741599],
#        [ 0.18467753],
#        [-2.15829111],
#        [ 2.15562705],
#        [-0.89490045],
#        [ 1.03780305],
#        [-0.93225969],
#        [-0.97202424],
#        [ 0.69832224],
#        [-0.915513  ],
#        [ 1.14474302],
#        [-0.6027759 ],
#        [ 0.35149332],
#        [ 0.45310778],
#        [-0.49574812],
#        [ 0.88505823],
#        [ 0.65164797],
#        [-1.77829065],
#        [-0.05015423],
#        [ 1.56613077],
#        [-1.61171712],
#        [ 0.87763477],
#        [-0.99262649],
#        [ 2.01221214],
#        [-2.02817992],
#        [ 0.71361863],
#        [-0.7489167 ],
#        [ 1.09476833],
#        [-1.2081265 ],
#        [ 1.6398594 ],
#        [-0.85573605],
#        [ 0.21147713],
#        [-0.05749942],
#        [ 0.11320664],
#        [-0.99124771],
#        [ 1.08940773],
#        [-1.61531834],
#        [ 2.60576579],
#        [-1.66288855],
#        [ 0.28262878],
#        [ 0.04342569],
#        [-0.57154902],
#        [ 0.47284423],
#        [-0.50709326],
#        [ 0.08754548],
#        [-0.63741274],
#        [ 0.40512964],
#        [ 0.09175474],
#        [ 0.61888387],
#        [ 0.53022134],
#        [-0.64598195],
#        [-0.40104783],
#        [-0.12750475],
#        [ 0.2811594 ],
#        [-0.13028456],
#        [ 1.07152686],
#        [-1.78151299],
#        [ 0.56255562],
#        [ 0.06587843],
#        [ 1.43558042],
#        [-1.53612025],
#        [ 0.36807476],
#        [ 0.08631008],
#        [ 0.22405283],
#        [-0.26596853],
#        [-0.00658658],
#        [ 0.64090451],
#        [-1.58740644],
#        [ 1.27619471],
#        [-0.89224654],
#        [ 0.15842284],
#        [-0.01066848],
#        [ 0.77419105],
#        [-0.88093611],
#        [ 0.61830324],
#        [-0.01882238],
#        [ 0.79812004],
#        [-1.99388083],
#        [ 1.8546679 ],
#        [-1.01754958],
#        [ 0.96949275],
#        [-1.02469424],
#        [ 0.93848301],
#        [-1.07603181],
#        [ 0.97046219],
#        [ 0.30669606],
#        [-0.71484821],
#        [ 1.21455519],
#        [-0.27183677]])

# %%
y_train, type(y_train)
# Out:
# (array([-0.84051577,  0.43027508, -0.18025785,  0.09243469,  0.19699376,
#         -0.88675546,  0.456268  ,  0.24774682, -0.02961474, -0.31654349,
#          0.12198815, -0.04442466,  0.59040934, -0.76734717,  0.39829577,
#          0.32893891, -0.72807519,  1.1279377 , -0.83854206,  0.19998117,
#          0.12513508, -0.39540212,  0.94208373, -0.10690206,  0.11027309,
#         -0.5202166 , -0.18584341,  0.77735496, -0.5586327 ,  0.17240607,
#         -0.69863262,  0.6644721 , -0.88565492,  0.84189738, -0.6262373 ,
#          0.44592695, -0.55738656,  1.29496299, -0.46272333, -0.42405417,
#         -0.25519219, -0.39960224,  1.16702684, -0.09759059, -0.34960554,
#          0.42284443, -0.01832377, -1.12287794,  0.30183349,  0.7879504 ,
#          0.64168988, -0.99732584,  1.00117106, -1.11464762,  1.28363775,
#         -2.3808626 ,  2.12409708, -1.15407963,  0.0686576 ,  2.22367412,
#         -2.86762041,  0.91922845,  0.0757552 , -0.70319902,  0.51291169,
#         -0.12325143, -0.40657705,  1.34142522, -1.53511985,  0.90136862,
#         -0.22113426,  0.80925549, -0.78330468,  0.88151156, -2.15986699,
#          2.16703857, -0.66997179,  0.0529162 ,  0.31370458, -1.06207751,
#          0.24756326,  0.85741599,  0.18467753, -2.15829111,  2.15562705,
#         -0.89490045,  1.03780305, -0.93225969, -0.97202424,  0.69832224,
#         -0.915513  ,  1.14474302, -0.6027759 ,  0.35149332,  0.45310778,
#         -0.49574812,  0.88505823,  0.65164797, -1.77829065, -0.05015423,
#          1.56613077, -1.61171712,  0.87763477, -0.99262649,  2.01221214,
#         -2.02817992,  0.71361863, -0.7489167 ,  1.09476833, -1.2081265 ,
#          1.6398594 , -0.85573605,  0.21147713, -0.05749942,  0.11320664,
#         -0.99124771,  1.08940773, -1.61531834,  2.60576579, -1.66288855,
#          0.28262878,  0.04342569, -0.57154902,  0.47284423, -0.50709326,
#          0.08754548, -0.63741274,  0.40512964,  0.09175474,  0.61888387,
#          0.53022134, -0.64598195, -0.40104783, -0.12750475,  0.2811594 ,
#         -0.13028456,  1.07152686, -1.78151299,  0.56255562,  0.06587843,
#          1.43558042, -1.53612025,  0.36807476,  0.08631008,  0.22405283,
#         -0.26596853, -0.00658658,  0.64090451, -1.58740644,  1.27619471,
#         -0.89224654,  0.15842284, -0.01066848,  0.77419105, -0.88093611,
#          0.61830324, -0.01882238,  0.79812004, -1.99388083,  1.8546679 ,
#         -1.01754958,  0.96949275, -1.02469424,  0.93848301, -1.07603181,
#          0.97046219,  0.30669606, -0.71484821,  1.21455519, -0.27183677,
#         -0.15670107]),
#  numpy.ndarray)

# %% [markdown]
# # Creando el modelo

# %%
(x_train.shape[0],1,1)
# Out:
# (171, 1, 1)

# %%
x_train = np.reshape(x_train,(x_train.shape[0],1,1))
x_val = np.reshape(x_val, (x_val.shape[0],1,1))
x_test = np.reshape(x_test, (x_test.shape[0],1,1))
len(x_val)
# Out:
# 56

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# 2025-07-25 19:13:05.923754: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/bianca_cal/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo1.compile(loss='mean_squared_error',optimizer="rmsprop")

# %%
epocas = 50
history= modelo1.fit(
    x = x_train,
    y = y_train,
    batch_size = lote,
    epochs = epocas,
    shuffle = False,
    validation_data = (x_val,y_val),
    verbose=1
)
# Out:
# Epoch 1/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.6224 - val_loss: 0.8987
# Epoch 2/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5153 - val_loss: 0.7217
# Epoch 3/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4451 - val_loss: 0.6128
# Epoch 4/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4083 - val_loss: 0.5581
# Epoch 5/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3938 - val_loss: 0.5345
# Epoch 6/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3897 - val_loss: 0.5249
# Epoch 7/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3891 - val_loss: 0.5209
# Epoch 8/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3894 - val_loss: 0.5192
# Epoch 9/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3897 - val_loss: 0.5184
# Epoch 10/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3899 - val_loss: 0.5181
# Epoch 11/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3900 - val_loss: 0.5179
# Epoch 12/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3901 - val_loss: 0.5179
# Epoch 13/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3901 - val_loss: 0.5178
# Epoch 14/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3900 - val_loss: 0.5179
# Epoch 15/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3900 - val_loss: 0.5179
# Epoch 16/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3899 - val_loss: 0.5179
# Epoch 17/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3899 - val_loss: 0.5180
# Epoch 18/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3898 - val_loss: 0.5180
# Epoch 19/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3898 - val_loss: 0.5180
# Epoch 20/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3897 - val_loss: 0.5180
# Epoch 21/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3897 - val_loss: 0.5181
# Epoch 22/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3896 - val_loss: 0.5181
# Epoch 23/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3896 - val_loss: 0.5181
# Epoch 24/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3896 - val_loss: 0.5181
# Epoch 25/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3895 - val_loss: 0.5182
# Epoch 26/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3895 - val_loss: 0.5182
# Epoch 27/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3895 - val_loss: 0.5182
# Epoch 28/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3895 - val_loss: 0.5182
# Epoch 29/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3894 - val_loss: 0.5182
# Epoch 30/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3894 - val_loss: 0.5182
# Epoch 31/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3894 - val_loss: 0.5182
# Epoch 32/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3894 - val_loss: 0.5182
# Epoch 33/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3893 - val_loss: 0.5182
# Epoch 34/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3893 - val_loss: 0.5182
# Epoch 35/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3893 - val_loss: 0.5182
# Epoch 36/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3893 - val_loss: 0.5182
# Epoch 37/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3892 - val_loss: 0.5182
# Epoch 38/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3892 - val_loss: 0.5182
# Epoch 39/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3892 - val_loss: 0.5182
# Epoch 40/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3892 - val_loss: 0.5182
# Epoch 41/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3892 - val_loss: 0.5182
# Epoch 42/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3892 - val_loss: 0.5182
# Epoch 43/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3891 - val_loss: 0.5182
# Epoch 44/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3891 - val_loss: 0.5182
# Epoch 45/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3891 - val_loss: 0.5182
# Epoch 46/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3891 - val_loss: 0.5182
# Epoch 47/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3891 - val_loss: 0.5182
# Epoch 48/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3891 - val_loss: 0.5181
# Epoch 49/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3890 - val_loss: 0.5181
# Epoch 50/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3890 - val_loss: 0.5181

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')

# %%
print("Pérdida en Train")
modelo1.evaluate(
    x = x_train,
    y = y_train
)
print("Pérdida en Validación")
modelo1.evaluate(
    x = x_val,
    y = y_val
)
print("Pérdida en Test")
modelo1.evaluate(
    x = x_test,
    y = y_test
)
# Out:
# Pérdida en Train
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4216
# Pérdida en Validación
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.5488
# Pérdida en Test
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1378
# 0.9375119805335999

# %%
prediccion_val = []

def prediccion_fun(data,modelo, batch_size,scaler,dif=False,dif_cant=1, Series = None , n=1):
    prediccion = [0]* (len(data))
    i=0
    for X in data:
        # X = np.reshape(X,(1,1,1))
        X = np.reshape(X, (1,) + X.shape)
        yhat = modelo1.predict(X, batch_size=batch_size,verbose=0)
        # invert scaling
        yhat = scaler.inverse_transform(yhat)
        if dif:
             # invert differencing
            yhat  = yhat + Series[(n+dif_cant*i)]
        # store
        prediccion[i]=yhat[0][0]
        i = i+1
    return prediccion


prediccion_val = prediccion_fun(x_val,modelo1, 1,scaler,dif=True,dif_cant=1, Series = sup_imp_h.values , n=train_end)
prediccion_test = prediccion_fun(x_test,modelo1, 1,scaler,dif=True,dif_cant=1, Series = sup_imp_h.values , n = len(sup_imp_h.values) - len(x_test))

# %%
# df_val = pd.DataFrame(prediccion_val,index=airPas[(train_prop):train_prop+val_prop].index) 
# df_test = pd.DataFrame(prediccion_test,index=airPas[train_prop+len(df_val):len(airPas)].index)
df_val = pd.DataFrame(prediccion_val, index=sup_imp_h[train_end+1:val_end].index)
df_test = pd.DataFrame(prediccion_test, index=sup_imp_h[val_end:].index[:len(prediccion_test)])


plt.plot(sup_imp_h, label='Serie original')
plt.plot(df_val, label='Predicción validación')
plt.plot(df_test, label='Predicción prueba')

plt.legend()
plt.title('Predicción de series temporales')
plt.xlabel('Fecha')
plt.ylabel('Gasolina Superior')
plt.grid(True)
plt.show()

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# /home/bianca_cal/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Segundo Modelo

# %%
# Supón que ya tienes sup_imp_h_diff_scaled definido y escalado
total_len = len(sup_imp_h_diff_scaled)

# Definir proporciones
train_prop = 0.6
val_prop = 0.2
test_prop = 0.2 

# Calcular índices
train_end = int(train_prop * total_len)
val_end = train_end + int(val_prop * total_len)

# Separar sin solapamientos
train = sup_imp_h_diff_scaled[:train_end]
validation = sup_imp_h_diff_scaled[train_end:val_end]
test = sup_imp_h_diff_scaled[val_end:]

# Redimensionar para LSTM univariante
train = train.reshape(-1, 1)
validation = validation.reshape(-1, 1)
test = test.reshape(-1, 1)

# %%
# Segundo Modelo
unidades =  32  # Aumentamos el número de unidades
paso = 6       # Aumentamos los lags a 6 (en el primero era 1)
caracteristicas = 1 # es univariada
lote = 1
epocas = 150   # Aumentamos el número de épocas

# %%
def supervisada(serie, retrasos=6):  # Ahora 6 lags
    serie_x = []
    serie_y = []
    for i in range(len(serie)-retrasos):
        valor = serie[i:(i+retrasos),0]
        valor_sig = serie[i+retrasos,0]
        serie_x.append(valor)
        serie_y.append(valor_sig)
    return np.array(serie_x), np.array(serie_y)

x_train2, y_train2 = supervisada(train, retrasos=6)
x_val2, y_val2 = supervisada(validation, retrasos=6)
x_test2, y_test2 = supervisada(test, retrasos=6)

# Reshape para LSTM: (samples, time_steps, features)
x_train2 = np.reshape(x_train2, (x_train2.shape[0], 6, 1))
x_val2 = np.reshape(x_val2, (x_val2.shape[0], 6, 1))
x_test2 = np.reshape(x_test2, (x_test2.shape[0], 6, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

modelo2 = Sequential()
modelo2.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False
))
modelo2.add(Dense(1))
modelo2.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 32)             │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,385 (17.13 KB)
#  Trainable params: 4,385 (17.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo2.compile(loss='mean_squared_error', optimizer="adam")

# %%
epocas = 100
history2 = modelo2.fit(
    x=x_train2,
    y=y_train2,
    batch_size=lote,
    epochs=epocas,
    shuffle=False,
    validation_data=(x_val2, y_val2),
    verbose=1
)
# Out:
# Epoch 1/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6514 - val_loss: 0.8538
# Epoch 2/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4588 - val_loss: 0.5141
# Epoch 3/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3621 - val_loss: 0.4553
# Epoch 4/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3418 - val_loss: 0.4296
# Epoch 5/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3350 - val_loss: 0.4173
# Epoch 6/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3315 - val_loss: 0.4101
# Epoch 7/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3287 - val_loss: 0.4052
# Epoch 8/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3263 - val_loss: 0.4017
# Epoch 9/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3244 - val_loss: 0.3990
# Epoch 10/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3228 - val_loss: 0.3969
# Epoch 11/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3215 - val_loss: 0.3951
# Epoch 12/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3204 - val_loss: 0.3937
# Epoch 13/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3195 - val_loss: 0.3924
# Epoch 14/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3187 - val_loss: 0.3914
# Epoch 15/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3180 - val_loss: 0.3905
# Epoch 16/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3173 - val_loss: 0.3898
# Epoch 17/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3168 - val_loss: 0.3892
# Epoch 18/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3162 - val_loss: 0.3886
# Epoch 19/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3157 - val_loss: 0.3882
# Epoch 20/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3153 - val_loss: 0.3878
# Epoch 21/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3148 - val_loss: 0.3874
# Epoch 22/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3144 - val_loss: 0.3871
# Epoch 23/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3139 - val_loss: 0.3868
# Epoch 24/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3135 - val_loss: 0.3865
# Epoch 25/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3131 - val_loss: 0.3863
# Epoch 26/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3126 - val_loss: 0.3860
# Epoch 27/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.
100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2189 - val_loss: 0.5389
# Epoch 92/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2161 - val_loss: 0.5456
# Epoch 93/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2133 - val_loss: 0.5523
# Epoch 94/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2105 - val_loss: 0.5592
# Epoch 95/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2078 - val_loss: 0.5661
# Epoch 96/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2051 - val_loss: 0.5731
# Epoch 97/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2024 - val_loss: 0.5802
# Epoch 98/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1997 - val_loss: 0.5873
# Epoch 99/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1970 - val_loss: 0.5944
# Epoch 100/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1943 - val_loss: 0.6016

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss (Modelo 2)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')
plt.show()

# %%
print("Pérdida en Train (Modelo 2)")
modelo2.evaluate(x_train2, y_train2)
print("Pérdida en Validación (Modelo 2)")
modelo2.evaluate(x_val2, y_val2)
print("Pérdida en Test (Modelo 2)")
modelo2.evaluate(x_test2, y_test2)
# Out:
# Pérdida en Train (Modelo 2)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1780
# Pérdida en Validación (Modelo 2)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.6576
# Pérdida en Test (Modelo 2)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.0621
# 0.9024221301078796

# %%
def prediccion_fun(data, modelo, batch_size, scaler, dif=False, dif_cant=1, Series=None, n=1):
    prediccion = [0] * (len(data))
    i = 0
    for X in data:
        X = np.reshape(X, (1,) + X.shape)
        yhat = modelo.predict(X, batch_size=batch_size, verbose=0)
        yhat = scaler.inverse_transform(yhat)
        if dif:
            yhat = yhat + Series[(n + dif_cant * i)]
        prediccion[i] = yhat[0][0]
        i = i + 1
    return prediccion

prediccion_val2 = prediccion_fun(x_val2, modelo2, 1, scaler, dif=True, dif_cant=1, Series=sup_imp_h.values, n=train_end)
prediccion_test2 = prediccion_fun(x_test2, modelo2, 1, scaler, dif=True, dif_cant=1, Series=sup_imp_h.values, n=len(sup_imp_h.values) - len(x_test2))

# %%
df_val2 = pd.DataFrame(prediccion_val2, index=sup_imp_h[train_end+paso:val_end].index)
df_test2 = pd.DataFrame(prediccion_test2, index=sup_imp_h[val_end:].index[:len(prediccion_test2)])

plt.plot(sup_imp_h, label='Serie original')
plt.plot(df_val2, label='Predicción validación (Modelo 2)')
plt.plot(df_test2, label='Predicción prueba (Modelo 2)')

plt.legend()
plt.title('Predicción de series temporales - Modelo 2')
plt.xlabel('Fecha')
plt.ylabel('Gasolina Superior')
plt.grid(True)
plt.show()

# %% [markdown]
# # Consumo

# %%
sup_con = pd.read_csv('./data/consumo.csv', parse_dates=['Fecha'], dayfirst=True)
sup_con.set_index('Fecha', inplace=True)
sup_con_h = sup_con['Gasolina superior']

sup_imp_h.head()
# Out:
# Fecha
# 2001-01-01    373963.96
# 2001-01-02    243091.07
# 2001-01-03    312084.38
# 2001-01-04    285054.89
# 2001-01-05    300913.67
# Name: Gasolina superior, dtype: float64

# %%
plt.plot(sup_imp_h)
plt.gca().set(title="Consumo Gasolina Superior", ylabel="cantidad" , xlabel="año")
plt.show()

# %%
# Se calcula la media móvil y la desviación estandar móvil de los últimos 12 meses.
mediaMovil = sup_con_h.rolling(window=12).mean()
deMovil = sup_con_h.rolling(window=12).std()
# Se grafican los resultados.
original = plt.plot(sup_con_h, color="blue", label="Original")
media = plt.plot(mediaMovil, color='red', label = 'Media Movil')
ds = plt.plot(deMovil,color='black', label = 'Desviación Estándar Móvil')
plt.legend(loc = 'best')
plt.title('Media y desviación estándar móvil')
plt.show(block=False)

# %%
descomposicion = seasonal_decompose(sup_con_h, period= 12)
descomposicion.plot()

# %%
print('Resultados del Test de Dickey Fuller')
dfTest = adfuller(sup_con_h, autolag='AIC')
salidaDf = pd.Series(dfTest[0:4], index=['Estadístico de prueba','p-value','# de retardos usados','# de observaciones usadas'])
for key,value in dfTest[4].items():
        salidaDf['Critical Value (%s)'%key] = value
print(salidaDf)
# Out:
# Resultados del Test de Dickey Fuller
# Estadístico de prueba         -0.179772
# p-value                        0.940890
# # de retardos usados          12.000000
# # de observaciones usadas    287.000000
# Critical Value (1%)           -3.453342
# Critical Value (5%)           -2.871664
# Critical Value (10%)          -2.572164
# dtype: float64

# %% [markdown]
# p-values es mayor a 0.05

# %%
print('Resultados del Test de Dickey Fuller para una diferenciación de la serie')
sup_con_h_diff = sup_con_h.diff()
sup_con_h_diff.fillna(0,inplace=True)
dfTest = adfuller(sup_con_h_diff)
salidaDf = pd.Series(dfTest[0:4], index=['Estadístico de prueba','p-value','# de retardos usados','# de observaciones usadas'])
for key,value in dfTest[4].items():
        salidaDf['Critical Value (%s)'%key] = value
print(salidaDf)
# Out:
# Resultados del Test de Dickey Fuller para una diferenciación de la serie
# Estadístico de prueba         -4.480786
# p-value                        0.000213
# # de retardos usados          16.000000
# # de observaciones usadas    283.000000
# Critical Value (1%)           -3.453670
# Critical Value (5%)           -2.871808
# Critical Value (10%)          -2.572241
# dtype: float64

# %%
plt.plot(sup_con_h_diff)

# %%
scaler = StandardScaler()
sup_con_h_diff_scaled = scaler.fit_transform(sup_con_h_diff.values.reshape(-1, 1))
sup_con_h_diff_scaled[1:7]
# Out:
# array([[-0.04502189],
#        [ 0.52365814],
#        [-0.41290885],
#        [ 0.05720588],
#        [-0.48379101],
#        [ 0.14849188]])

# %%
total_len = len(sup_con_h_diff_scaled)

# Definir proporciones
train_prop = 0.6
val_prop = 0.2
test_prop = 0.2 

# Calcular índices
train_end = int(train_prop * total_len)
val_end = train_end + int(val_prop * total_len)

# Separar sin solapamientos
train = sup_con_h_diff_scaled[:train_end]
validation = sup_con_h_diff_scaled[train_end:val_end]
test = sup_con_h_diff_scaled[val_end:]

# Si hace falta, redimensionar (por ejemplo para un LSTM univariante)
train = train.reshape(-1, 1)
validation = validation.reshape(-1, 1)
test = test.reshape(-1, 1)

# Verificar tamaños
print(f"Total registros: {total_len}")
print(f"Train: {len(train)} | Validation: {len(validation)} | Test: {len(test)}")
# Out:
# Total registros: 300
# Train: 180 | Validation: 60 | Test: 60

# %%
train, type(train)
# Out:
# (array([[-3.59703411e-02],
#         [-4.50218942e-02],
#         [ 5.23658137e-01],
#         [-4.12908851e-01],
#         [ 5.72058844e-02],
#         [-4.83791011e-01],
#         [ 1.48491879e-01],
#         [ 3.04895466e-01],
#         [ 4.38542003e-02],
#         [-9.65154522e-02],
#         [-1.06794323e-01],
#         [ 1.03487816e+00],
#         [-1.58303419e+00],
#         [-7.21425850e-03],
#         [ 1.21775773e+00],
#         [-3.00845485e-02],
#         [-4.94602762e-01],
#         [-6.67252834e-01],
#         [ 9.30522332e-01],
#         [-8.43519135e-02],
#         [-5.92741105e-01],
#         [-3.21194976e-01],
#         [-3.54600957e-01],
#         [ 4.71073321e-01],
#         [-2.36521198e-01],
#         [ 1.28786479e+00],
#         [-1.31148694e+00],
#         [-5.13598021e-01],
#         [ 1.10782185e-02],
#         [-1.84584461e-01],
#         [-3.80697504e-01],
#         [ 1.70869851e-01],
#         [ 1.60915252e-01],
#         [ 4.09059602e-01],
#         [-6.85933556e-01],
#         [-1.61230302e-02],
#         [-2.29359748e-02],
#         [ 1.54093579e+00],
#         [-1.33681465e+00],
#         [ 1.69199355e-01],
#         [ 5.87561393e-01],
#         [-9.69391734e-01],
#         [ 3.49108099e-01],
#         [ 3.89859570e-02],
#         [ 2.25008110e-01],
#         [ 2.75956503e-01],
#         [-1.31889883e+00],
#         [ 7.99496053e-01],
#         [-4.94255776e-01],
#         [ 1.06363099e+00],
#         [-8.15565629e-01],
#         [-1.13329552e+00],
#         [ 1.18159277e+00],
#         [-1.40426993e-01],
#         [-1.72343041e-01],
#         [-6.70929791e-02],
#         [ 5.00436920e-01],
#         [-2.25713619e-01],
#         [-9.04905764e-01],
#         [ 1.13919272e+00],
#         [-6.26733742e-01],
#         [ 9.70983708e-01],
#         [-8.59221508e-01],
#         [-6.66140483e-01],
#         [ 1.10983608e+00],
#         [ 2.44361608e-02],
#         [-2.67361286e-01],
#         [-9.67482265e-01],
#         [ 1.16557298e+00],
#         [ 5.24792635e-02],
#         [-7.65797038e-01],
#         [ 1.08718622e+00],
#         [-5.79619355e-01],
#         [ 2.33826564e+00]]),
#  numpy.ndarray)

# %%
from operator import concat


def supervisada(serie,retrasos = 1):
    serie_x = []
    serie_y = []
    for i in range(len(serie)-retrasos):
        valor = serie[i:(i+retrasos),0]
        valor_sig = serie[i+retrasos,0]
        serie_x.append(valor)
        serie_y.append(valor_sig)
    return np.array(serie_x), np.array(serie_y)

x_train,y_train = supervisada(train)
x_val,y_val = supervisada(validation)
x_test,y_test = supervisada(test)

# %%
x_train
# Out:
# array([[-3.59703411e-02],
#        [-4.50218942e-02],
#        [ 5.23658137e-01],
#        [-4.12908851e-01],
#        [ 5.72058844e-02],
#        [-4.83791011e-01],
#        [ 1.48491879e-01],
#        [ 3.04895466e-01],
#        [ 4.38542003e-02],
#        [-9.65154522e-02],
#        [-1.06794323e-01],
#        [ 1.03487816e+00],
#        [-1.58303419e+00],
#        [-7.21425850e-03],
#        [ 1.21775773e+00],
#        [-3.00845485e-02],
#        [-4.94602762e-01],
#        [-6.67252834e-01],
#        [ 9.30522332e-01],
#        [-8.43519135e-02],
#        [-5.92741105e-01],
#        [ 9.34471999e-01],
#        [-3.69072873e-01],
#        [ 1.16170142e+00],
#        [-8.38561916e-01],
#        [-4.99957529e-01],
#        [ 8.01414331e-01],
#        [-1.58887285e-01],
#        [-1.44617256e-01],
#        [-1.26739680e-01],
#        [ 6.31719556e-01],
#        [-2.11874948e-01],
#        [-1.08282183e+00],
#        [ 7.61467524e-01],
#        [ 2.75168551e-02],
#        [ 3.42103698e-01],
#        [-5.95247796e-01],
#        [-5.17064178e-01],
#        [ 1.05885304e-01],
#        [ 3.23632512e-01],
#        [ 2.70664319e-01],
#        [-1.04847664e+00],
#        [ 6.64887028e-01],
#        [-5.34224603e-01],
#        [-1.98771277e-01],
#        [ 9.69589967e-01],
#        [-1.45918458e+00],
#         -3.19323624e-02,  1.91413221e-01,  4.27992972e-01, -5.42749533e-01,
#         -9.45995749e-01,  9.40221269e-01, -6.40314201e-01,  2.20288675e-01,
#         -8.64194508e-04, -7.31299103e-01,  1.31042773e+00, -1.44463594e+00,
#          1.33374561e-02,  1.69012938e+00, -1.85785669e+00, -1.57705398e-01,
#          6.06833997e-02,  8.10072076e-01, -3.21194976e-01, -3.54600957e-01,
#          4.71073321e-01, -2.36521198e-01,  1.28786479e+00, -1.31148694e+00,
#         -5.13598021e-01,  1.10782185e-02, -1.84584461e-01, -3.80697504e-01,
#          1.70869851e-01,  1.60915252e-01,  4.09059602e-01, -6.85933556e-01,
#         -1.61230302e-02, -2.29359748e-02,  1.54093579e+00, -1.33681465e+00,
#          1.69199355e-01,  5.87561393e-01, -9.69391734e-01,  3.49108099e-01,
#          3.89859570e-02,  2.25008110e-01,  2.75956503e-01, -1.31889883e+00,
#          7.99496053e-01, -4.94255776e-01,  1.06363099e+00, -8.15565629e-01,
#         -1.13329552e+00,  1.18159277e+00, -1.40426993e-01, -1.72343041e-01,
#         -6.70929791e-02,  5.00436920e-01, -2.25713619e-01, -9.04905764e-01,
#          1.13919272e+00, -6.26733742e-01,  9.70983708e-01, -8.59221508e-01,
#         -6.66140483e-01,  1.10983608e+00,  2.44361608e-02, -2.67361286e-01,
#         -9.67482265e-01,  1.16557298e+00,  5.24792635e-02, -7.65797038e-01,
#          1.08718622e+00, -5.79619355e-01,  2.33826564e+00]),
#  numpy.ndarray)

# %% [markdown]
# # Creando el modelo

# %%
(x_train.shape[0],1,1)
# Out:
# (179, 1, 1)

# %%
x_train = np.reshape(x_train,(x_train.shape[0],1,1))
x_val = np.reshape(x_val, (x_val.shape[0],1,1))
x_test = np.reshape(x_test, (x_test.shape[0],1,1))
len(x_val)
# Out:
# 59

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# /home/bianca_cal/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_5 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_7 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo1.compile(loss='mean_squared_error',optimizer="rmsprop")

# %%
epocas = 50
history= modelo1.fit(
    x = x_train,
    y = y_train,
    batch_size = lote,
    epochs = epocas,
    shuffle = False,
    validation_data = (x_val,y_val),
    verbose=1
)
# Out:
# Epoch 1/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.5005 - val_loss: 0.7784
# Epoch 2/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4760 - val_loss: 0.7252
# Epoch 3/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4607 - val_loss: 0.6872
# Epoch 4/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4518 - val_loss: 0.6605
# Epoch 5/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4470 - val_loss: 0.6417
# Epoch 6/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4445 - val_loss: 0.6284
# Epoch 7/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4433 - val_loss: 0.6187
# Epoch 8/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4426 - val_loss: 0.6114
# Epoch 9/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4422 - val_loss: 0.6058
# Epoch 10/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4418 - val_loss: 0.6014
# Epoch 11/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4414 - val_loss: 0.5977
# Epoch 12/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4410 - val_loss: 0.5946
# Epoch 13/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4406 - val_loss: 0.5919
# Epoch 14/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4401 - val_loss: 0.5896
# Epoch 15/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4397 - val_loss: 0.5875
# Epoch 16/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4393 - val_loss: 0.5857
# Epoch 17/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4389 - val_loss: 0.5840
# Epoch 18/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4385 - val_loss: 0.5825
# Epoch 19/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4382 - val_loss: 0.5811
# Epoch 20/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4379 - val_loss: 0.5798
# Epoch 21/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4376 - val_loss: 0.5787
# Epoch 22/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4373 - val_loss: 0.5776
# Epoch 23/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4370 - val_loss: 0.5766
# Epoch 24/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4368 - val_loss: 0.5757
# Epoch 25/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4366 - val_loss: 0.5749
# Epoch 26/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4364 - val_loss: 0.5741
# Epoch 27/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4362 - val_loss: 0.5734
# Epoch 28/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4360 - val_loss: 0.5727
# Epoch 29/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4359 - val_loss: 0.5721
# Epoch 30/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4358 - val_loss: 0.5715
# Epoch 31/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4356 - val_loss: 0.5710
# Epoch 32/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4355 - val_loss: 0.5705
# Epoch 33/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4354 - val_loss: 0.5700
# Epoch 34/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4353 - val_loss: 0.5696
# Epoch 35/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4352 - val_loss: 0.5692
# Epoch 36/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4351 - val_loss: 0.5689
# Epoch 37/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4350 - val_loss: 0.5685
# Epoch 38/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4349 - val_loss: 0.5682
# Epoch 39/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4349 - val_loss: 0.5679
# Epoch 40/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4348 - val_loss: 0.5676
# Epoch 41/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4348 - val_loss: 0.5674
# Epoch 42/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4347 - val_loss: 0.5671
# Epoch 43/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4346 - val_loss: 0.5669
# Epoch 44/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4346 - val_loss: 0.5667
# Epoch 45/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4346 - val_loss: 0.5665
# Epoch 46/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4345 - val_loss: 0.5663
# Epoch 47/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4345 - val_loss: 0.5662
# Epoch 48/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4344 - val_loss: 0.5660
# Epoch 49/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4344 - val_loss: 0.5659
# Epoch 50/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4344 - val_loss: 0.5657

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')

# %%
print("Pérdida en Train")
modelo1.evaluate(
    x = x_train,
    y = y_train
)
print("Pérdida en Validación")
modelo1.evaluate(
    x = x_val,
    y = y_val
)
print("Pérdida en Test")
modelo1.evaluate(
    x = x_test,
    y = y_test
)
# Out:
# Pérdida en Train
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4762
# Pérdida en Validación
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.5631
# Pérdida en Test
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.0367
# 1.890676736831665

# %%
prediccion_val = []

def prediccion_fun(data,modelo, batch_size,scaler,dif=False,dif_cant=1, Series = None , n=1):
    prediccion = [0]* (len(data))
    i=0
    for X in data:
        # X = np.reshape(X,(1,1,1))
        X = np.reshape(X, (1,) + X.shape)
        yhat = modelo1.predict(X, batch_size=batch_size,verbose=0)
        # invert scaling
        yhat = scaler.inverse_transform(yhat)
        if dif:
             # invert differencing
            yhat  = yhat + Series[(n+dif_cant*i)]
        # store
        prediccion[i]=yhat[0][0]
        i = i+1
    return prediccion


prediccion_val = prediccion_fun(x_val,modelo1, 1,scaler,dif=True,dif_cant=1, Series = sup_imp_h.values , n=train_end)
prediccion_test = prediccion_fun(x_test,modelo1, 1,scaler,dif=True,dif_cant=1, Series = sup_imp_h.values , n = len(sup_imp_h.values) - len(x_test))

# %%
df_val = pd.DataFrame(prediccion_val, index=sup_con_h[train_end+1:val_end].index)
df_test = pd.DataFrame(prediccion_test, index=sup_con_h[val_end:].index[:len(prediccion_test)])


plt.plot(sup_con_h, label='Serie original')
plt.plot(df_val, label='Predicción validación')
plt.plot(df_test, label='Predicción prueba')

plt.legend()
plt.title('Predicción de series temporales')
plt.xlabel('Fecha')
plt.ylabel('Gasolina Superior')
plt.grid(True)
plt.show()

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# /home/bianca_cal/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Segundo Modelo

# %%
# Supón que ya tienes sup_imp_h_diff_scaled definido y escalado
total_len = len(sup_con_h_diff_scaled)

# Definir proporciones
train_prop = 0.6
val_prop = 0.2
test_prop = 0.2 

# Calcular índices
train_end = int(train_prop * total_len)
val_end = train_end + int(val_prop * total_len)

# Separar sin solapamientos
train = sup_con_h_diff_scaled[:train_end]
validation = sup_con_h_diff_scaled[train_end:val_end]
test = sup_con_h_diff_scaled[val_end:]

# Redimensionar para LSTM univariante
train = train.reshape(-1, 1)
validation = validation.reshape(-1, 1)
test = test.reshape(-1, 1)

# %%
# Segundo Modelo
unidades =  32  # Aumentamos el número de unidades
paso = 6       # Aumentamos los lags a 6 (en el primero era 1)
caracteristicas = 1 # es univariada
lote = 1
epocas = 150   # Aumentamos el número de épocas

# %%
def supervisada(serie, retrasos=6):  # Ahora 6 lags
    serie_x = []
    serie_y = []
    for i in range(len(serie)-retrasos):
        valor = serie[i:(i+retrasos),0]
        valor_sig = serie[i+retrasos,0]
        serie_x.append(valor)
        serie_y.append(valor_sig)
    return np.array(serie_x), np.array(serie_y)

x_train2, y_train2 = supervisada(train, retrasos=6)
x_val2, y_val2 = supervisada(validation, retrasos=6)
x_test2, y_test2 = supervisada(test, retrasos=6)

# Reshape para LSTM: (samples, time_steps, features)
x_train2 = np.reshape(x_train2, (x_train2.shape[0], 6, 1))
x_val2 = np.reshape(x_val2, (x_val2.shape[0], 6, 1))
x_test2 = np.reshape(x_test2, (x_test2.shape[0], 6, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

modelo2 = Sequential()
modelo2.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False
))
modelo2.add(Dense(1))
modelo2.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_9 (LSTM)                   │ (None, 32)             │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,385 (17.13 KB)
#  Trainable params: 4,385 (17.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo2.compile(loss='mean_squared_error', optimizer="adam")

# %%
epocas = 100
history2 = modelo2.fit(
    x=x_train2,
    y=y_train2,
    batch_size=lote,
    epochs=epocas,
    shuffle=False,
    validation_data=(x_val2, y_val2),
    verbose=1
)
# Out:
# Epoch 1/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.5252 - val_loss: 0.6324
# Epoch 2/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4206 - val_loss: 0.5391
# Epoch 3/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3818 - val_loss: 0.4991
# Epoch 4/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3636 - val_loss: 0.4773
# Epoch 5/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3564 - val_loss: 0.4670
# Epoch 6/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3533 - val_loss: 0.4617
# Epoch 7/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3509 - val_loss: 0.4579
# Epoch 8/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3482 - val_loss: 0.4542
# Epoch 9/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.
100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2396 - val_loss: 0.3541
# Epoch 74/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2372 - val_loss: 0.3553
# Epoch 75/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2347 - val_loss: 0.3565
# Epoch 76/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2322 - val_loss: 0.3578
# Epoch 77/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2295 - val_loss: 0.3591
# Epoch 78/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2267 - val_loss: 0.3605
# Epoch 79/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2239 - val_loss: 0.3620
# Epoch 80/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2209 - val_loss: 0.3635
# Epoch 81/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2179 - val_loss: 0.3651
# Epoch 82/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2148 - val_loss: 0.3668
# Epoch 83/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2116 - val_loss: 0.3687
# Epoch 84/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2084 - val_loss: 0.3706
# Epoch 85/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2050 - val_loss: 0.3727
# Epoch 86/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2017 - val_loss: 0.3748
# Epoch 87/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1982 - val_loss: 0.3771
# Epoch 88/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1947 - val_loss: 0.3793
# Epoch 89/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1912 - val_loss: 0.3816
# Epoch 90/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1877 - val_loss: 0.3839
# Epoch 91/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1842 - val_loss: 0.3862
# Epoch 92/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1807 - val_loss: 0.3883
# Epoch 93/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1772 - val_loss: 0.3904
# Epoch 94/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1738 - val_loss: 0.3924
# Epoch 95/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1705 - val_loss: 0.3942
# Epoch 96/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1672 - val_loss: 0.3960
# Epoch 97/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1640 - val_loss: 0.3977
# Epoch 98/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1608 - val_loss: 0.3993
# Epoch 99/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1577 - val_loss: 0.4009
# Epoch 100/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1547 - val_loss: 0.4024

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss (Modelo 2)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')
plt.show()

# %%
print("Pérdida en Train (Modelo 2)")
modelo2.evaluate(x_train2, y_train2)
print("Pérdida en Validación (Modelo 2)")
modelo2.evaluate(x_val2, y_val2)
print("Pérdida en Test (Modelo 2)")
modelo2.evaluate(x_test2, y_test2)
# Out:
# Pérdida en Train (Modelo 2)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1414
# Pérdida en Validación (Modelo 2)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4504
# Pérdida en Test (Modelo 2)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.1135
# 2.012927532196045

# %%
def prediccion_fun(data, modelo, batch_size, scaler, dif=False, dif_cant=1, Series=None, n=1):
    prediccion = [0] * (len(data))
    i = 0
    for X in data:
        X = np.reshape(X, (1,) + X.shape)
        yhat = modelo.predict(X, batch_size=batch_size, verbose=0)
        yhat = scaler.inverse_transform(yhat)
        if dif:
            yhat = yhat + Series[(n + dif_cant * i)]
        prediccion[i] = yhat[0][0]
        i = i + 1
    return prediccion

prediccion_val2 = prediccion_fun(x_val2, modelo2, 1, scaler, dif=True, dif_cant=1, Series=sup_imp_h.values, n=train_end)
prediccion_test2 = prediccion_fun(x_test2, modelo2, 1, scaler, dif=True, dif_cant=1, Series=sup_imp_h.values, n=len(sup_imp_h.values) - len(x_test2))

# %%
df_val2 = pd.DataFrame(prediccion_val2, index=sup_con_h[train_end+paso:val_end].index)
df_test2 = pd.DataFrame(prediccion_test2, index=sup_con_h[val_end:].index[:len(prediccion_test2)])

plt.plot(sup_imp_h, label='Serie original')
plt.plot(df_val2, label='Predicción validación (Modelo 2)')
plt.plot(df_test2, label='Predicción prueba (Modelo 2)')

plt.legend()
plt.title('Predicción de series temporales - Modelo 2')
plt.xlabel('Fecha')
plt.ylabel('Gasolina Superior')
plt.grid(True)
plt.show()

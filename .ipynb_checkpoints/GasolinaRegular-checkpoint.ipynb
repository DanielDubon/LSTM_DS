# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

import warnings
warnings.filterwarnings("ignore")

# %%
reg_imp = pd.read_csv('./data/importacion.csv', parse_dates=['Fecha'], dayfirst=True)
reg_imp.set_index('Fecha', inplace=True)
reg_imp_h = reg_imp['Gasolina regular']

plt.plot(reg_imp_h)
plt.gca().set(title="Imp Gasolina Regular", ylabel="cantidad" , xlabel="año")
plt.show()

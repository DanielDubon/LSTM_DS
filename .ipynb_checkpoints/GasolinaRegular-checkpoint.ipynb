# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa as tsa
import statsmodels as sm
from datetime import datetime
import os
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.metrics import mean_squared_error
# Out:
# 2025-07-26 20:37:38.216553: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-26 20:37:38.305546: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-26 20:37:38.379809: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753583858.450321 1277305 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753583858.470082 1277305 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1753583858.648851 1277305 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753583858.648964 1277305 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753583858.648968 1277305 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753583858.648972 1277305 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-26 20:37:38.687980: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
sup_imp = pd.read_csv('./data/importacion.csv', parse_dates=['Fecha'], dayfirst=True)
sup_imp.set_index('Fecha', inplace=True)
sup_imp_h = sup_imp['Gasolina regular']

sup_imp_h.head()
# Out:
# Fecha
# 2001-01-01    177776.50
# 2001-01-02    123115.99
# 2001-01-03    161726.42
# 2001-01-04    127338.74
# 2001-01-05    168730.19
# Name: Gasolina regular, dtype: float64

# %%
plt.plot(sup_imp_h)
plt.gca().set(title="Imp Gasolina Regular", ylabel="cantidad" , xlabel="año")
plt.show()

# %%
mediaMovil = sup_imp_h.rolling(window=12).mean()
deMovil = sup_imp_h.rolling(window=12).std()


original = plt.plot(sup_imp_h, color="blue", label="Original")
media = plt.plot(mediaMovil, color='red', label = 'Media Movil')
ds = plt.plot(deMovil,color='black', label = 'Desviación Estándar Móvil')
plt.legend(loc = 'best')
plt.title('Media y desviación estándar móvil')
plt.show(block=False)

# %%
descomposicion = seasonal_decompose(sup_imp_h, period= 12)
descomposicion.plot()

# %%
print('Resultados del Test de Dickey Fuller')
dfTest = adfuller(sup_imp_h, autolag='AIC')
salidaDf = pd.Series(dfTest[0:4], index=['Estadístico de prueba','p-value','# de retardos usados','# de observaciones usadas'])
for key,value in dfTest[4].items():
        salidaDf['Critical Value (%s)'%key] = value
print(salidaDf)
# Out:
# Resultados del Test de Dickey Fuller
# Estadístico de prueba          0.830167
# p-value                        0.992108
# # de retardos usados           9.000000
# # de observaciones usadas    278.000000
# Critical Value (1%)           -3.454094
# Critical Value (5%)           -2.871993
# Critical Value (10%)          -2.572340
# dtype: float64

# %%
print('Resultados del Test de Dickey Fuller para una diferenciación de la serie')
sup_imp_h_diff = sup_imp_h.diff()
sup_imp_h_diff.fillna(0,inplace=True)
dfTest = adfuller(sup_imp_h_diff)
salidaDf = pd.Series(dfTest[0:4], index=['Estadístico de prueba','p-value','# de retardos usados','# de observaciones usadas'])
for key,value in dfTest[4].items():
        salidaDf['Critical Value (%s)'%key] = value
print(salidaDf)
# Out:
# Resultados del Test de Dickey Fuller para una diferenciación de la serie
# Estadístico de prueba       -1.023316e+01
# p-value                      4.967668e-18
# # de retardos usados         8.000000e+00
# # de observaciones usadas    2.790000e+02
# Critical Value (1%)         -3.454008e+00
# Critical Value (5%)         -2.871956e+00
# Critical Value (10%)        -2.572320e+00
# dtype: float64

# %%
plt.plot(sup_imp_h_diff)

# %%
scaler = StandardScaler()
sup_imp_h_diff_scaled = scaler.fit_transform(sup_imp_h_diff.values.reshape(-1, 1))
sup_imp_h_diff_scaled[1:7]
# Out:
# array([[-0.41838396],
#        [ 0.26504895],
#        [-0.26983695],
#        [ 0.28542658],
#        [-0.13386558],
#        [-0.13949932]])

# %% [markdown]
# # Entrenamiento

# %%
total_len = len(sup_imp_h_diff_scaled)

train_prop = 0.6
val_prop = 0.2
test_prop = 0.2 

train_end = int(train_prop * total_len)
val_end = train_end + int(val_prop * total_len)

train = sup_imp_h_diff_scaled[:train_end]
validation = sup_imp_h_diff_scaled[train_end:val_end]
test = sup_imp_h_diff_scaled[val_end:]

train = train.reshape(-1, 1)
validation = validation.reshape(-1, 1)
test = test.reshape(-1, 1)

print(f"Total registros: {total_len}")
print(f"Train: {len(train)} | Validation: {len(validation)} | Test: {len(test)}")
# Out:
# Total registros: 288
# Train: 172 | Validation: 57 | Test: 59

# %%
train, type(train)
# Out:
# (array([[-0.01786488],
#         [-0.41838396],
#         [ 0.26504895],
#         [-0.26983695],
#         [ 0.28542658],
#         [-0.13386558],
#         [-0.13949932],
#         [ 0.00460047],
#         [ 0.67295214],
#         [-0.69267044],
#         [ 0.1601266 ],
#         [-0.13967393],
#         [ 0.19732793],
#         [-0.26801243],
#         [-0.30930178],
#         [ 0.60983895],
#         [ 0.01504318],
#         [-0.44123656],
#         [ 0.60758094],
#         [-0.59389328],
#         [ 0.07857755],
#         [ 0.26401923],
#         [-0.32738205],
#         [ 0.08773027],
#         [ 0.42670855],
#         [-0.11882757],
#         [-0.40792564],
#         [ 0.19145981],
#         [ 0.56947678],
#         [-0.66067977],
#         [-0.37387385],
#         [ 0.24764807],
#         [ 0.03572526],
#         [ 0.01474566],
#         [ 0.15767056],
#         [-0.34134257],
#         [ 0.06969381],
#         [-0.20462549],
#         [ 0.91711167],
#         [-0.24049338],
#         [-0.50710426],
#         [-0.34794052],
#         [ 0.11941201],
#         [ 0.39625817],
#         [ 0.05472314],
#         [-0.13943784],
#         [ 0.08421048],
#         [ 0.06461512],
#         [-0.19900084],
#         [-0.19569787],
#         [ 0.27202858],
#         [ 0.10541369],
#         [-0.32383948],
#         [ 0.35296925],
#         [-0.51171202],
#         [-0.0335156 ],
#         [-0.69781097],
#         [ 0.45336238],
#         [ 0.86649821],
#         [-1.18031465],
#         [ 1.74898848],
#         [-1.50866454],
#         [ 1.01335625],
#         [-0.36194932],
#         [-0.78440047],
#         [ 0.54891226],
#         [-0.24223378],
#         [-0.26477379],
#         [ 1.58645539],
#         [-1.5727116 ],
#         [ 0.10911637],
#         [ 0.44370444],
#         [ 0.38683653],
#         [ 0.05193917],
#         [ 0.18173853],
#         [-1.7139576 ],
#         [ 1.03405526],
#         [-0.51861787],
#         [ 0.40415996],
#         [ 0.88813659],
#         [-1.26564999],
#         [ 0.94278832],
#         [-0.18520519],
#         [-0.51007669],
#         [-0.85481958],
#         [ 0.9123071 ],
#         [ 0.03320874],
#         [ 0.20015396],
#         [-0.22981788],
#         [-0.49260276],
#         [ 0.37994299],
#         [-0.70482622],
#         [ 1.09769082],
#         [ 0.47611269],
#         [-1.39300507],
#         [ 0.4806441 ],
#         [-0.28102372],
#         [ 2.80949666],
#         [-2.14198188],
#         [-0.86960325],
#         [ 1.41184535],
#         [-0.1179658 ],
#         [-0.01614133],
#         [-1.14200308],
#         [-0.37479688],
#         [ 1.54494768],
#         [-1.29176255],
#         [ 0.64388949],
#         [-0.87961863],
#         [ 1.16981311],
#         [-1.32365737],
#         [ 1.99943595],
#         [-1.14028443],
#         [-0.0038878 ],
#         [-0.30978986],
#         [ 0.27900448],
#         [-0.55799067],
#         [ 1.32528011],
#         [-1.86841935],
#         [ 2.11667982],
#         [-1.31596493],
#         [ 0.64073615],
#         [-0.40252147],
#         [ 0.23798243],
#         [-0.01374029],
#         [-0.71819138],
#         [-0.32861034],
#         [ 0.07931901],
#         [ 0.41316708],
#         [-0.17142734],
#         [-0.0318487 ],
#         [ 0.93482132],
#         [-0.38084272],
#         [-0.49194344],
#         [-0.00388274],
#         [-0.49812696],
#         [ 0.3619689 ],
#         [ 0.55939014],
#         [-1.32458993],
#         [ 0.8720087 ],
#         [-0.47457891],
#         [ 1.24943682],
#         [-1.31410069],
#         [ 0.64586349],
#         [ 0.7766903 ],
#         [-1.19694702],
#         [ 1.47607377],
#         [-1.22473038],
#         [ 0.0344714 ],
#         [ 0.06995687],
#         [-0.27273193],
#         [-0.29332088],
#         [ 0.56365021],
#         [-0.16167333],
#         [ 0.78647999],
#         [-1.34298279],
#         [ 2.01756795],
#         [-1.30350689],
#         [ 1.15461902],
#         [-1.96247187],
#         [ 1.52615064],
#         [-1.26830111],
#         [ 1.49950018],
#         [-1.10899148],
#         [ 0.52037638],
#         [-0.91474572],
#         [ 0.83555257],
#         [ 0.84868868],
#         [-0.89459868],
#         [ 1.28123764],
#         [-0.71527405],
#         [ 0.5941806 ]]),
#  numpy.ndarray)

# %%
from operator import concat


def supervisada(serie,retrasos = 1):
    serie_x = []
    serie_y = []
    for i in range(len(serie)-retrasos):
        valor = serie[i:(i+retrasos),0]
        valor_sig = serie[i+retrasos,0]
        serie_x.append(valor)
        serie_y.append(valor_sig)
    return np.array(serie_x), np.array(serie_y)

x_train,y_train = supervisada(train)
x_val,y_val = supervisada(validation)
x_test,y_test = supervisada(test)

# %%
x_train
# Out:
# array([[-0.01786488],
#        [-0.41838396],
#        [ 0.26504895],
#        [-0.26983695],
#        [ 0.28542658],
#        [-0.13386558],
#        [-0.13949932],
#        [ 0.00460047],
#        [ 0.67295214],
#        [-0.69267044],
#        [ 0.1601266 ],
#        [-0.13967393],
#        [ 0.19732793],
#        [-0.26801243],
#        [-0.30930178],
#        [ 0.60983895],
#        [ 0.01504318],
#        [-0.44123656],
#        [ 0.60758094],
#        [-0.59389328],
#        [ 0.07857755],
#        [ 0.26401923],
#        [-0.32738205],
#        [ 0.08773027],
#        [ 0.42670855],
#        [-0.11882757],
#        [-0.40792564],
#        [ 0.19145981],
#        [ 0.56947678],
#        [-0.66067977],
#        [-0.37387385],
#        [ 0.24764807],
#        [ 0.03572526],
#        [ 0.01474566],
#        [ 0.15767056],
#        [-0.34134257],
#        [ 0.06969381],
#        [-0.20462549],
#        [ 0.91711167],
#        [-0.24049338],
#        [-0.50710426],
#        [-0.34794052],
#        [ 0.11941201],
#        [ 0.39625817],
#        [ 0.05472314],
#        [-0.13943784],
#        [ 0.08421048],
#        [ 0.06461512],
#        [-0.19900084],
#        [-0.19569787],
#        [ 0.27202858],
#        [ 0.10541369],
#        [-0.32383948],
#        [ 0.35296925],
#        [-0.51171202],
#        [-0.0335156 ],
#        [-0.69781097],
#        [ 0.45336238],
#        [ 0.86649821],
#        [-1.18031465],
#        [ 1.74898848],
#        [-1.50866454],
#        [ 1.01335625],
#        [-0.36194932],
#        [-0.78440047],
#        [ 0.54891226],
#        [-0.24223378],
#        [-0.26477379],
#        [ 1.58645539],
#        [-1.5727116 ],
#        [ 0.10911637],
#        [ 0.44370444],
#        [ 0.38683653],
#        [ 0.05193917],
#        [ 0.18173853],
#        [-1.7139576 ],
#        [ 1.03405526],
#        [-0.51861787],
#        [ 0.40415996],
#        [ 0.88813659],
#        [-1.26564999],
#        [ 0.94278832],
#        [-0.18520519],
#        [-0.51007669],
#        [-0.85481958],
#        [ 0.9123071 ],
#        [ 0.03320874],
#        [ 0.20015396],
#        [-0.22981788],
#        [-0.49260276],
#        [ 0.37994299],
#        [-0.70482622],
#        [ 1.09769082],
#        [ 0.47611269],
#        [-1.39300507],
#        [ 0.4806441 ],
#        [-0.28102372],
#        [ 2.80949666],
#        [-2.14198188],
#        [-0.86960325],
#        [ 1.41184535],
#        [-0.1179658 ],
#        [-0.01614133],
#        [-1.14200308],
#        [-0.37479688],
#        [ 1.54494768],
#        [-1.29176255],
#        [ 0.64388949],
#        [-0.87961863],
#        [ 1.16981311],
#        [-1.32365737],
#        [ 1.99943595],
#        [-1.14028443],
#        [-0.0038878 ],
#        [-0.30978986],
#        [ 0.27900448],
#        [-0.55799067],
#        [ 1.32528011],
#        [-1.86841935],
#        [ 2.11667982],
#        [-1.31596493],
#        [ 0.64073615],
#        [-0.40252147],
#        [ 0.23798243],
#        [-0.01374029],
#        [-0.71819138],
#        [-0.32861034],
#        [ 0.07931901],
#        [ 0.41316708],
#        [-0.17142734],
#        [-0.0318487 ],
#        [ 0.93482132],
#        [-0.38084272],
#        [-0.49194344],
#        [-0.00388274],
#        [-0.49812696],
#        [ 0.3619689 ],
#        [ 0.55939014],
#        [-1.32458993],
#        [ 0.8720087 ],
#        [-0.47457891],
#        [ 1.24943682],
#        [-1.31410069],
#        [ 0.64586349],
#        [ 0.7766903 ],
#        [-1.19694702],
#        [ 1.47607377],
#        [-1.22473038],
#        [ 0.0344714 ],
#        [ 0.06995687],
#        [-0.27273193],
#        [-0.29332088],
#        [ 0.56365021],
#        [-0.16167333],
#        [ 0.78647999],
#        [-1.34298279],
#        [ 2.01756795],
#        [-1.30350689],
#        [ 1.15461902],
#        [-1.96247187],
#        [ 1.52615064],
#        [-1.26830111],
#        [ 1.49950018],
#        [-1.10899148],
#        [ 0.52037638],
#        [-0.91474572],
#        [ 0.83555257],
#        [ 0.84868868],
#        [-0.89459868],
#        [ 1.28123764],
#        [-0.71527405]])

# %%
y_train, type(y_train)
# Out:
# (array([-0.41838396,  0.26504895, -0.26983695,  0.28542658, -0.13386558,
#         -0.13949932,  0.00460047,  0.67295214, -0.69267044,  0.1601266 ,
#         -0.13967393,  0.19732793, -0.26801243, -0.30930178,  0.60983895,
#          0.01504318, -0.44123656,  0.60758094, -0.59389328,  0.07857755,
#          0.26401923, -0.32738205,  0.08773027,  0.42670855, -0.11882757,
#         -0.40792564,  0.19145981,  0.56947678, -0.66067977, -0.37387385,
#          0.24764807,  0.03572526,  0.01474566,  0.15767056, -0.34134257,
#          0.06969381, -0.20462549,  0.91711167, -0.24049338, -0.50710426,
#         -0.34794052,  0.11941201,  0.39625817,  0.05472314, -0.13943784,
#          0.08421048,  0.06461512, -0.19900084, -0.19569787,  0.27202858,
#          0.10541369, -0.32383948,  0.35296925, -0.51171202, -0.0335156 ,
#         -0.69781097,  0.45336238,  0.86649821, -1.18031465,  1.74898848,
#         -1.50866454,  1.01335625, -0.36194932, -0.78440047,  0.54891226,
#         -0.24223378, -0.26477379,  1.58645539, -1.5727116 ,  0.10911637,
#          0.44370444,  0.38683653,  0.05193917,  0.18173853, -1.7139576 ,
#          1.03405526, -0.51861787,  0.40415996,  0.88813659, -1.26564999,
#          0.94278832, -0.18520519, -0.51007669, -0.85481958,  0.9123071 ,
#          0.03320874,  0.20015396, -0.22981788, -0.49260276,  0.37994299,
#         -0.70482622,  1.09769082,  0.47611269, -1.39300507,  0.4806441 ,
#         -0.28102372,  2.80949666, -2.14198188, -0.86960325,  1.41184535,
#         -0.1179658 , -0.01614133, -1.14200308, -0.37479688,  1.54494768,
#         -1.29176255,  0.64388949, -0.87961863,  1.16981311, -1.32365737,
#          1.99943595, -1.14028443, -0.0038878 , -0.30978986,  0.27900448,
#         -0.55799067,  1.32528011, -1.86841935,  2.11667982, -1.31596493,
#          0.64073615, -0.40252147,  0.23798243, -0.01374029, -0.71819138,
#         -0.32861034,  0.07931901,  0.41316708, -0.17142734, -0.0318487 ,
#          0.93482132, -0.38084272, -0.49194344, -0.00388274, -0.49812696,
#          0.3619689 ,  0.55939014, -1.32458993,  0.8720087 , -0.47457891,
#          1.24943682, -1.31410069,  0.64586349,  0.7766903 , -1.19694702,
#          1.47607377, -1.22473038,  0.0344714 ,  0.06995687, -0.27273193,
#         -0.29332088,  0.56365021, -0.16167333,  0.78647999, -1.34298279,
#          2.01756795, -1.30350689,  1.15461902, -1.96247187,  1.52615064,
#         -1.26830111,  1.49950018, -1.10899148,  0.52037638, -0.91474572,
#          0.83555257,  0.84868868, -0.89459868,  1.28123764, -0.71527405,
#          0.5941806 ]),
#  numpy.ndarray)

# %% [markdown]
# # Creando el modelo

# %%
(x_train.shape[0],1,1)
# Out:
# (171, 1, 1)

# %%
x_train = np.reshape(x_train,(x_train.shape[0],1,1))
x_val = np.reshape(x_val, (x_val.shape[0],1,1))
x_test = np.reshape(x_test, (x_test.shape[0],1,1))
len(x_val)
# Out:
# 56

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# 2025-07-26 20:37:42.971353: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/danidubon12/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo1.compile(loss='mean_squared_error',optimizer="rmsprop")

# %%
epocas = 50
history= modelo1.fit(
    x = x_train,
    y = y_train,
    batch_size = lote,
    epochs = epocas,
    shuffle = False,
    validation_data = (x_val,y_val),
    verbose=1
)
# Out:
# Epoch 1/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3484 - val_loss: 1.1635
# Epoch 2/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3181 - val_loss: 1.0241
# Epoch 3/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2923 - val_loss: 0.9083
# Epoch 4/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2743 - val_loss: 0.8266
# Epoch 5/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2645 - val_loss: 0.7769
# Epoch 6/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2608 - val_loss: 0.7493
# Epoch 7/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2600 - val_loss: 0.7346
# Epoch 8/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2603 - val_loss: 0.7269
# Epoch 9/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2608 - val_loss: 0.7228
# Epoch 10/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2612 - val_loss: 0.7206
# Epoch 11/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2614 - val_loss: 0.7194
# Epoch 12/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2615 - val_loss: 0.7189
# Epoch 13/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2615 - val_loss: 0.7186
# Epoch 14/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2615 - val_loss: 0.7185
# Epoch 15/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2615 - val_loss: 0.7185
# Epoch 16/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2614 - val_loss: 0.7185
# Epoch 17/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2614 - val_loss: 0.7186
# Epoch 18/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2613 - val_loss: 0.7187
# Epoch 19/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2612 - val_loss: 0.7188
# Epoch 20/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2612 - val_loss: 0.7188
# Epoch 21/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2611 - val_loss: 0.7189
# Epoch 22/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2611 - val_loss: 0.7189
# Epoch 23/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2610 - val_loss: 0.7190
# Epoch 24/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2610 - val_loss: 0.7190
# Epoch 25/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2609 - val_loss: 0.7190
# Epoch 26/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2609 - val_loss: 0.7190
# Epoch 27/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2608 - val_loss: 0.7190
# Epoch 28/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2608 - val_loss: 0.7190
# Epoch 29/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2608 - val_loss: 0.7190
# Epoch 30/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2607 - val_loss: 0.7190
# Epoch 31/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2607 - val_loss: 0.7190
# Epoch 32/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2607 - val_loss: 0.7190
# Epoch 33/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2606 - val_loss: 0.7189
# Epoch 34/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2606 - val_loss: 0.7189
# Epoch 35/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2606 - val_loss: 0.7188
# Epoch 36/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2605 - val_loss: 0.7188
# Epoch 37/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2605 - val_loss: 0.7187
# Epoch 38/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2605 - val_loss: 0.7187
# Epoch 39/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2605 - val_loss: 0.7186
# Epoch 40/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2604 - val_loss: 0.7186
# Epoch 41/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2604 - val_loss: 0.7185
# Epoch 42/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2604 - val_loss: 0.7184
# Epoch 43/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2604 - val_loss: 0.7184
# Epoch 44/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2604 - val_loss: 0.7183
# Epoch 45/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2603 - val_loss: 0.7182
# Epoch 46/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2603 - val_loss: 0.7181
# Epoch 47/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2603 - val_loss: 0.7181
# Epoch 48/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2603 - val_loss: 0.7180
# Epoch 49/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2603 - val_loss: 0.7179
# Epoch 50/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2602 - val_loss: 0.7178

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')

# %%
print("Pérdida en Train")
modelo1.evaluate(
    x = x_train,
    y = y_train
)
print("Pérdida en Validación")
modelo1.evaluate(
    x = x_val,
    y = y_val
)
print("Pérdida en Test")
modelo1.evaluate(
    x = x_test,
    y = y_test
)
# Out:
# Pérdida en Train
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3050
# Pérdida en Validación
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6450
# Pérdida en Test
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.1272
# 1.0288238525390625

# %%
prediccion_val = []

def prediccion_fun(data,modelo, batch_size,scaler,dif=False,dif_cant=1, Series = None , n=1):
    prediccion = [0]* (len(data))
    i=0
    for X in data:
        # X = np.reshape(X,(1,1,1))
        X = np.reshape(X, (1,) + X.shape)
        yhat = modelo1.predict(X, batch_size=batch_size,verbose=0)
        # invert scaling
        yhat = scaler.inverse_transform(yhat)
        if dif:
             # invert differencing
            yhat  = yhat + Series[(n+dif_cant*i)]
        # store
        prediccion[i]=yhat[0][0]
        i = i+1
    return prediccion


prediccion_val = prediccion_fun(x_val,modelo1, 1,scaler,dif=True,dif_cant=1, Series = sup_imp_h.values , n=train_end)
prediccion_test = prediccion_fun(x_test,modelo1, 1,scaler,dif=True,dif_cant=1, Series = sup_imp_h.values , n = len(sup_imp_h.values) - len(x_test))

# %%
# df_val = pd.DataFrame(prediccion_val,index=airPas[(train_prop):train_prop+val_prop].index) 
# df_test = pd.DataFrame(prediccion_test,index=airPas[train_prop+len(df_val):len(airPas)].index)
df_val = pd.DataFrame(prediccion_val, index=sup_imp_h[train_end+1:val_end].index)
df_test = pd.DataFrame(prediccion_test, index=sup_imp_h[val_end:].index[:len(prediccion_test)])


plt.plot(sup_imp_h, label='Serie original')
plt.plot(df_val, label='Predicción validación')
plt.plot(df_test, label='Predicción prueba')

plt.legend()
plt.title('Predicción de series temporales')
plt.xlabel('Fecha')
plt.ylabel('Gasolina Regular')
plt.grid(True)
plt.show()

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# /home/danidubon12/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Segundo Model

# %%
# Supón que ya tienes sup_imp_h_diff_scaled definido y escalado
total_len = len(sup_imp_h_diff_scaled)

# Definir proporciones
train_prop = 0.6
val_prop = 0.2
test_prop = 0.2 

# Calcular índices
train_end = int(train_prop * total_len)
val_end = train_end + int(val_prop * total_len)

# Separar sin solapamientos
train = sup_imp_h_diff_scaled[:train_end]
validation = sup_imp_h_diff_scaled[train_end:val_end]
test = sup_imp_h_diff_scaled[val_end:]

# Redimensionar para LSTM univariante
train = train.reshape(-1, 1)
validation = validation.reshape(-1, 1)
test = test.reshape(-1, 1)

# %%
# Segundo Modelo
unidades =  32  # Aumentamos el número de unidades
paso = 6       # Aumentamos los lags a 6 (en el primero era 1)
caracteristicas = 1 # es univariada
lote = 1
epocas = 150   # Aumentamos el número de épocas

# %%
def supervisada(serie, retrasos=6):  # Ahora 6 lags
    serie_x = []
    serie_y = []
    for i in range(len(serie)-retrasos):
        valor = serie[i:(i+retrasos),0]
        valor_sig = serie[i+retrasos,0]
        serie_x.append(valor)
        serie_y.append(valor_sig)
    return np.array(serie_x), np.array(serie_y)

x_train2, y_train2 = supervisada(train, retrasos=6)
x_val2, y_val2 = supervisada(validation, retrasos=6)
x_test2, y_test2 = supervisada(test, retrasos=6)

# Reshape para LSTM: (samples, time_steps, features)
x_train2 = np.reshape(x_train2, (x_train2.shape[0], 6, 1))
x_val2 = np.reshape(x_val2, (x_val2.shape[0], 6, 1))
x_test2 = np.reshape(x_test2, (x_test2.shape[0], 6, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

modelo2 = Sequential()
modelo2.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False
))
modelo2.add(Dense(1))
modelo2.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 32)             │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,385 (17.13 KB)
#  Trainable params: 4,385 (17.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo2.compile(loss='mean_squared_error', optimizer="adam")

# %%
epocas = 100
history2 = modelo2.fit(
    x=x_train2,
    y=y_train2,
    batch_size=lote,
    epochs=epocas,
    shuffle=False,
    validation_data=(x_val2, y_val2),
    verbose=1
)
# Out:
# Epoch 1/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4029 - val_loss: 1.1705
# Epoch 2/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3096 - val_loss: 0.7764
# Epoch 3/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2550 - val_loss: 0.6339
# Epoch 4/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2474 - val_loss: 0.5864
# Epoch 5/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2390 - val_loss: 0.5635
# Epoch 6/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2339 - val_loss: 0.5520
# Epoch 7/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2303 - val_loss: 0.5450
# Epoch 8/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2275 - val_loss: 0.5397
# Epoch 9/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2253 - val_loss: 0.5354
# Epoch 10/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2235 - val_loss: 0.5316
# Epoch 11/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2219 - val_loss: 0.5282
# Epoch 12/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2205 - val_loss: 0.5252
# Epoch 13/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2192 - val_loss: 0.5225
# Epoch 14/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2180 - val_loss: 0.5204
# Epoch 15/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2168 - val_loss: 0.5188
# Epoch 16/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2157 - val_loss: 0.5180
# Epoch 17/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2147 - val_loss: 0.5179
# Epoch 18/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2138 - val_loss: 0.5186
# Epoch 19/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2129 - val_loss: 0.5199
# Epoch 20/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2122 - val_loss: 0.5215
# Epoch 21/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2116 - val_loss: 0.5234
# Epoch 22/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2111 - val_loss: 0.5254
# Epoch 23/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2106 - val_loss: 0.5272
# Epoch 24/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2102 - val_loss: 0.5290
# Epoch 25/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2097 - val_loss: 0.5306
# Epoch 26/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2093 - val_loss: 0.5321
# Epoch 27/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2089 - val_loss: 0.5335
# Epoch 28/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2085 - val_loss: 0.5349
# Epoch 29/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2080 - val_loss: 0.5361
# Epoch 30/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2076 - val_loss: 0.5374
# Epoch 31/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2071 - val_loss: 0.5387
# Epoch 32/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2065 - val_loss: 0.5399
# Epoch 33/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2059 - val_loss: 0.5412
# Epoch 34/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2053 - val_loss: 0.5427
# Epoch 35/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2047 - val_loss: 0.5442
# Epoch 36/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2040 - val_loss: 0.5459
# Epoch 37/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2032 - val_loss: 0.5479
# Epoch 38/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2024 - val_loss: 0.5502
# Epoch 39/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2016 - val_loss: 0.5529
# Epoch 40/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2007 - val_loss: 0.5559
# Epoch 41/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1998 - val_loss: 0.5595
# Epoch 42/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1989 - val_loss: 0.5635
# Epoch 43/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1979 - val_loss: 0.5680
# Epoch 44/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1969 - val_loss: 0.5730
# Epoch 45/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1960 - val_loss: 0.5783
# Epoch 46/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1950 - val_loss: 0.5839
# Epoch 47/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1940 - val_loss: 0.5899
# Epoch 48/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1931 - val_loss: 0.5960
# Epoch 49/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1922 - val_loss: 0.6026
# Epoch 50/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1913 - val_loss: 0.6095
# Epoch 51/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1904 - val_loss: 0.6170
# Epoch 52/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1895 - val_loss: 0.6250
# Epoch 53/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1886 - val_loss: 0.6337
# Epoch 54/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1876 - val_loss: 0.6430
# Epoch 55/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1867 - val_loss: 0.6527
# Epoch 56/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1857 - val_loss: 0.6629
# Epoch 57/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1847 - val_loss: 0.6733
# Epoch 58/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1837 - val_loss: 0.6840
# Epoch 59/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1827 - val_loss: 0.6946
# Epoch 60/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1818 - val_loss: 0.7052
# Epoch 61/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1808 - val_loss: 0.7156
# Epoch 62/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1798 - val_loss: 0.7257
# Epoch 63/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1788 - val_loss: 0.7356
# Epoch 64/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1778 - val_loss: 0.7452
# Epoch 65/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1768 - val_loss: 0.7547
# Epoch 66/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1757 - val_loss: 0.7640
# Epoch 67/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1746 - val_loss: 0.7733
# Epoch 68/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1734 - val_loss: 0.7827
# Epoch 69/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1721 - val_loss: 0.7924
# Epoch 70/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1708 - val_loss: 0.8024
# Epoch 71/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1694 - val_loss: 0.8128
# Epoch 72/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1679 - val_loss: 0.8238
# Epoch 73/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1663 - val_loss: 0.8352
# Epoch 74/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1646 - val_loss: 0.8471
# Epoch 75/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1629 - val_loss: 0.8593
# Epoch 76/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1611 - val_loss: 0.8717
# Epoch 77/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1592 - val_loss: 0.8843
# Epoch 78/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1573 - val_loss: 0.8969
# Epoch 79/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1553 - val_loss: 0.9096
# Epoch 80/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1533 - val_loss: 0.9226
# Epoch 81/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1513 - val_loss: 0.9357
# Epoch 82/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1492 - val_loss: 0.9491
# Epoch 83/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1471 - val_loss: 0.9626
# Epoch 84/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1449 - val_loss: 0.9758
# Epoch 85/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1427 - val_loss: 0.9886
# Epoch 86/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1405 - val_loss: 1.0005
# Epoch 87/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1382 - val_loss: 1.0114
# Epoch 88/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1360 - val_loss: 1.0209
# Epoch 89/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1337 - val_loss: 1.0290
# Epoch 90/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1315 - val_loss: 1.0357
# Epoch 91/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1292 - val_loss: 1.0415
# Epoch 92/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1270 - val_loss: 1.0468
# Epoch 93/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1249 - val_loss: 1.0525
# Epoch 94/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1228 - val_loss: 1.0602
# Epoch 95/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1208 - val_loss: 1.0706
# Epoch 96/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1188 - val_loss: 1.0803
# Epoch 97/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1170 - val_loss: 1.0761
# Epoch 98/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1150 - val_loss: 1.0540
# Epoch 99/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1129 - val_loss: 1.0323
# Epoch 100/100
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1111 - val_loss: 1.0181

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss (Modelo 2)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')
plt.show()

# %%
print("Pérdida en Train (Modelo 2)")
modelo2.evaluate(x_train2, y_train2)
print("Pérdida en Validación (Modelo 2)")
modelo2.evaluate(x_val2, y_val2)
print("Pérdida en Test (Modelo 2)")
modelo2.evaluate(x_test2, y_test2)
# Out:
# Pérdida en Train (Modelo 2)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1090
# Pérdida en Validación (Modelo 2)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.8699
# Pérdida en Test (Modelo 2)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.5478
# 1.4384257793426514

# %%
def prediccion_fun(data, modelo, batch_size, scaler, dif=False, dif_cant=1, Series=None, n=1):
    prediccion = [0] * (len(data))
    i = 0
    for X in data:
        X = np.reshape(X, (1,) + X.shape)
        yhat = modelo.predict(X, batch_size=batch_size, verbose=0)
        yhat = scaler.inverse_transform(yhat)
        if dif:
            yhat = yhat + Series[(n + dif_cant * i)]
        prediccion[i] = yhat[0][0]
        i = i + 1
    return prediccion

prediccion_val2 = prediccion_fun(x_val2, modelo2, 1, scaler, dif=True, dif_cant=1, Series=sup_imp_h.values, n=train_end)
prediccion_test2 = prediccion_fun(x_test2, modelo2, 1, scaler, dif=True, dif_cant=1, Series=sup_imp_h.values, n=len(sup_imp_h.values) - len(x_test2))

# %%
df_val2 = pd.DataFrame(prediccion_val2, index=sup_imp_h[train_end+paso:val_end].index)
df_test2 = pd.DataFrame(prediccion_test2, index=sup_imp_h[val_end:].index[:len(prediccion_test2)])

plt.plot(sup_imp_h, label='Serie original')
plt.plot(df_val2, label='Predicción validación (Modelo 2)')
plt.plot(df_test2, label='Predicción prueba (Modelo 2)')

plt.legend()
plt.title('Predicción de series temporales - Modelo 2')
plt.xlabel('Fecha')
plt.ylabel('Gasolina Regular')
plt.grid(True)
plt.show()

# %%
sup_con = pd.read_csv('./data/consumo.csv', parse_dates=['Fecha'], dayfirst=True)
sup_con.set_index('Fecha', inplace=True)
sup_con_h = sup_con['Gasolina regular']

sup_imp_h.head()
# Out:
# Fecha
# 2001-01-01    177776.50
# 2001-01-02    123115.99
# 2001-01-03    161726.42
# 2001-01-04    127338.74
# 2001-01-05    168730.19
# Name: Gasolina regular, dtype: float64

# %%
plt.plot(sup_imp_h)
plt.gca().set(title="Consumo Gasolina Regular", ylabel="cantidad" , xlabel="año")
plt.show()

# %%
# Se calcula la media móvil y la desviación estandar móvil de los últimos 12 meses.
mediaMovil = sup_con_h.rolling(window=12).mean()
deMovil = sup_con_h.rolling(window=12).std()
# Se grafican los resultados.
original = plt.plot(sup_con_h, color="blue", label="Original")
media = plt.plot(mediaMovil, color='red', label = 'Media Movil')
ds = plt.plot(deMovil,color='black', label = 'Desviación Estándar Móvil')
plt.legend(loc = 'best')
plt.title('Media y desviación estándar móvil')
plt.show(block=False)

# %%
descomposicion = seasonal_decompose(sup_con_h, period= 12)
descomposicion.plot()

# %%
print('Resultados del Test de Dickey Fuller')
dfTest = adfuller(sup_con_h, autolag='AIC')
salidaDf = pd.Series(dfTest[0:4], index=['Estadístico de prueba','p-value','# de retardos usados','# de observaciones usadas'])
for key,value in dfTest[4].items():
        salidaDf['Critical Value (%s)'%key] = value
print(salidaDf)
# Out:
# Resultados del Test de Dickey Fuller
# Estadístico de prueba          2.478789
# p-value                        0.999043
# # de retardos usados          14.000000
# # de observaciones usadas    285.000000
# Critical Value (1%)           -3.453505
# Critical Value (5%)           -2.871735
# Critical Value (10%)          -2.572202
# dtype: float64

# %%
print('Resultados del Test de Dickey Fuller para una diferenciación de la serie')
sup_con_h_diff = sup_con_h.diff()
sup_con_h_diff.fillna(0,inplace=True)
dfTest = adfuller(sup_con_h_diff)
salidaDf = pd.Series(dfTest[0:4], index=['Estadístico de prueba','p-value','# de retardos usados','# de observaciones usadas'])
for key,value in dfTest[4].items():
        salidaDf['Critical Value (%s)'%key] = value
print(salidaDf)
# Out:
# Resultados del Test de Dickey Fuller para una diferenciación de la serie
# Estadístico de prueba         -4.372644
# p-value                        0.000332
# # de retardos usados          16.000000
# # de observaciones usadas    283.000000
# Critical Value (1%)           -3.453670
# Critical Value (5%)           -2.871808
# Critical Value (10%)          -2.572241
# dtype: float64

# %%
plt.plot(sup_con_h_diff)

# %%
scaler = StandardScaler()
sup_con_h_diff_scaled = scaler.fit_transform(sup_con_h_diff.values.reshape(-1, 1))
sup_con_h_diff_scaled[1:7]
# Out:
# array([[ 0.01283202],
#        [ 0.53837341],
#        [-0.52821624],
#        [-0.12182156],
#        [-0.38504394],
#        [ 0.17691121]])

# %%
total_len = len(sup_con_h_diff_scaled)

# Definir proporciones
train_prop = 0.6
val_prop = 0.2
test_prop = 0.2 

# Calcular índices
train_end = int(train_prop * total_len)
val_end = train_end + int(val_prop * total_len)

# Separar sin solapamientos
train = sup_con_h_diff_scaled[:train_end]
validation = sup_con_h_diff_scaled[train_end:val_end]
test = sup_con_h_diff_scaled[val_end:]

# Si hace falta, redimensionar (por ejemplo para un LSTM univariante)
train = train.reshape(-1, 1)
validation = validation.reshape(-1, 1)
test = test.reshape(-1, 1)

# Verificar tamaños
print(f"Total registros: {total_len}")
print(f"Train: {len(train)} | Validation: {len(validation)} | Test: {len(test)}")
# Out:
# Total registros: 300
# Train: 180 | Validation: 60 | Test: 60

# %%
train, type(train)
# Out:
# (array([[-5.91026109e-02],
#         [ 1.28320202e-02],
#         [ 5.38373409e-01],
#         [-5.28216235e-01],
#         [-1.21821565e-01],
#         [-3.85043944e-01],
#         [ 1.76911211e-01],
#         [ 2.85687363e-01],
#         [-1.70816214e-01],
#         [-6.65885727e-02],
#         [-1.68264142e-01],
#         [ 4.59219291e-01],
#         [-1.69118607e+00],
#         [ 1.97437219e-01],
#         [ 6.17773312e-01],
#         [-1.41594016e-01],
#         [-4.62411264e-01],
#         [ 4.11412684e-01],
#         [ 2.79929621e-01],
#         [-3.16689643e-01],
#         [-4.66776558e-01],
#         [ 8.61931679e-01],
#         [-4.30920419e-01],
#         [ 2.62087551e-01],
#         [-6.29943653e-01],
#         [-4.87618148e-01],
#         [ 6.78559641e-01],
#         [-2.57178353e-01],
#         [-1.50888215e-01],
#         [-3.94478734e-01],
#         [ 2.91457568e-01],
#         [ 2.93432136e-02],
#         [-7.47747530e-01],
#         [ 5.76109576e-01],
#         [ 5.38827901e-02],
#         [-2.58784927e-01],
#         [-2.06315433e-01],
#         [-2.92398842e-01],
#         [ 3.66876558e-01],
#         [ 3.78646863e-01],
#         [-5.22681656e-01],
#         [-8.58761668e-01],
#         [ 9.02090609e-02],
#         [-1.25223164e-01],
#         [ 1.79954917e-02],
#         [ 8.02302731e-01],
#         [-1.07625340e+00],
#         [ 6.28196724e-01],
#         [ 1.37664191e-01],
#         [-6.49517433e-01],
#         [ 5.93133527e-01],
#         [-6.59248361e-01],
#         [-5.98483220e-01],
#         [ 4.16192337e-02],
#         [ 3.86099359e-01],
#         [ 5.58858536e-01],
#         [-3.87951731e-01],
#         [ 9.25305541e-02],
#         [ 2.94521152e-01],
#         [ 4.94869529e-01],
#         [-7.27941676e-01],
#         [-3.36445143e-01],
#         [ 7.53107666e-01],
#         [-2.01530319e-01],
#         [-1.02121808e+00],
#         [ 3.17639116e-01],
#         [ 2.31550929e-01],
#         [-8.71557112e-02],
#         [-4.55935362e-01],
#         [-1.71441394e-01],
#         [-2.34071357e-01],
#         [ 1.33145037e+00],
#         [-8.03994820e-01],
#         [-3.23366459e-01],
#         [ 7.51823653e-01],
#         [-2.98491110e-01],
#         [-7.82606008e-02],
#         [-7.12193761e-01],
#         [ 2.83512194e-01],
#         [-3.55102775e-02],
#         [-2.29410672e-01],
#         [-9.17226688e-02],
#         [ 2.73042132e-03],
#         [ 6.48710269e-01],
#         [-4.92242937e-01],
#         [-3.47485261e-01],
#         [ 7.89128575e-01],
#         [-5.94635918e-01],
#         [ 1.12011853e-01],
#         [-2.31770553e-01],
#         [ 7.31240027e-04],
#         [ 3.56969892e-01],
#         [-7.90068353e-01],
#         [ 3.77350324e-01],
#         [-2.24470800e-01],
#         [ 7.95343593e-01],
#         [-1.02500940e+00],
#         [-3.55727805e-03],
#         [ 3.86784615e-01],
#         [-6.09420073e-02],
#         [ 1.43977132e-02],
#         [-9.55974227e-01],
#         [ 6.38458108e-01],
#         [-8.75500634e-02],
#         [-2.90538008e-01],
#         [ 4.57912594e-01],
#         [-6.73107209e-02],
#         [ 1.42705461e+00],
#         [-6.76089593e-01],
#         [-5.28398206e-01],
#         [ 8.30198539e-01],
#         [-4.55470649e-02],
#         [-4.06003192e-01],
#         [-6.67797977e-01],
#         [ 7.03429506e-01],
#         [-4.40771996e-01],
#         [-5.28646483e-01],
#         [ 4.39797818e-01],
#         [-1.47644276e+00],
#         [ 2.05114006e+00],
#         [-1.39181868e+00],
#         [ 6.22053170e-02],
#         [ 1.75505421e+00],
#         [-1.70712597e+00],
#         [-4.57176500e-01],
#         [ 2.64781710e-01],
#         [ 6.09055187e-01],
#         [-3.02960352e-01],
#         [-1.07525175e-01],
#         [ 1.41711910e-01],
#         [-9.84448536e-02],
#         [ 1.12131747e+00],
#         [-9.49464424e-01],
#         [-4.52648678e-01],
#         [ 2.43824955e-01],
#         [ 4.42121868e-02],
#         [-8.64769931e-01],
#         [ 8.59713385e-01],
#         [-3.29668368e-01],
#         [-6.30018186e-01],
#         [-5.04283577e-02],
#         [-4.24470193e-01],
#         [-3.24758907e-01],
#         [ 1.44313008e+00],
#         [-8.00553336e-01],
#         [-2.63519148e-01],
#         [ 8.52081099e-01],
#         [-7.48879236e-01],
#         [-7.38157193e-01],
#         [ 5.80000751e-01],
#         [-7.55855432e-01],
#         [ 5.91618188e-01],
#         [-8.30860626e-01],
#         [ 7.67029147e-01],
#         [ 2.22841778e-01],
#         [ 8.81889092e-01],
#         [-6.18012130e-01],
#         [-7.65195746e-01],
#         [ 1.27241669e+00],
#         [ 3.64544346e-01],
#         [-4.81355874e-01],
#         [-6.95618005e-01],
#         [ 6.03692545e-01],
#         [-7.01855351e-01],
#         [-1.03235118e+00],
#         [ 1.56520228e+00],
#         [-2.55537628e-01],
#         [ 7.71764115e-01],
#         [-7.52835471e-01],
#         [-5.90308199e-02],
#         [ 5.32350439e-01],
#         [ 2.72075232e-01],
#         [-4.68359700e-01],
#         [-7.99960063e-01],
#         [ 9.78946602e-01],
#         [-5.15364142e-01],
#         [ 1.06191138e+00],
#         [-7.44967870e-01],
#         [-5.64630435e-02],
#         [ 2.93978375e+00]]),
#  numpy.ndarray)

# %%
from operator import concat


def supervisada(serie,retrasos = 1):
    serie_x = []
    serie_y = []
    for i in range(len(serie)-retrasos):
        valor = serie[i:(i+retrasos),0]
        valor_sig = serie[i+retrasos,0]
        serie_x.append(valor)
        serie_y.append(valor_sig)
    return np.array(serie_x), np.array(serie_y)

x_train,y_train = supervisada(train)
x_val,y_val = supervisada(validation)
x_test,y_test = supervisada(test)

# %%
x_train
# Out:
# array([[-5.91026109e-02],
#        [ 1.28320202e-02],
#        [ 5.38373409e-01],
#        [-5.28216235e-01],
#        [-1.21821565e-01],
#        [-3.85043944e-01],
#        [ 1.76911211e-01],
#        [ 2.85687363e-01],
#        [-1.70816214e-01],
#        [-6.65885727e-02],
#        [-1.68264142e-01],
#        [ 4.59219291e-01],
#        [-1.69118607e+00],
#        [ 1.97437219e-01],
#        [ 6.17773312e-01],
#        [-1.41594016e-01],
#        [-4.62411264e-01],
#        [ 4.11412684e-01],
#        [ 2.79929621e-01],
#        [-3.16689643e-01],
#        [-4.66776558e-01],
#        [ 8.61931679e-01],
#        [-4.30920419e-01],
#        [ 2.62087551e-01],
#        [-6.29943653e-01],
#        [-4.87618148e-01],
#        [ 6.78559641e-01],
#        [-2.57178353e-01],
#        [-1.50888215e-01],
#        [-3.94478734e-01],
#        [ 2.91457568e-01],
#        [ 2.93432136e-02],
#        [-7.47747530e-01],
#        [ 5.76109576e-01],
#        [ 5.38827901e-02],
#        [-2.58784927e-01],
#        [-2.06315433e-01],
#        [-2.92398842e-01],
#        [ 3.66876558e-01],
#        [ 3.78646863e-01],
#        [-5.22681656e-01],
#        [-8.58761668e-01],
#        [ 9.02090609e-02],
#        [-1.25223164e-01],
#        [ 1.79954917e-02],
#        [ 8.02302731e-01],
#        [-1.07625340e+00],
#        [ 6.28196724e-01],
#        [ 1.37664191e-01],
#        [-6.49517433e-01],
#        [ 5.93133527e-01],
#        [-6.59248361e-01],
#        [-5.98483220e-01],
#        [ 4.16192337e-02],
#        [ 3.86099359e-01],
#        [ 5.58858536e-01],
#        [-3.87951731e-01],
#        [ 9.25305541e-02],
#        [ 2.94521152e-01],
#        [ 4.94869529e-01],
#        [-7.27941676e-01],
#        [-3.36445143e-01],
#        [ 7.53107666e-01],
#        [-2.01530319e-01],
#        [-1.02121808e+00],
#        [ 3.17639116e-01],
#        [ 2.31550929e-01],
#        [-8.71557112e-02],
#        [-4.55935362e-01],
#        [-1.71441394e-01],
#        [-2.34071357e-01],
#        [ 1.33145037e+00],
#        [-8.03994820e-01],
#        [-3.23366459e-01],
#        [ 7.51823653e-01],
#        [-2.98491110e-01],
#        [-7.82606008e-02],
#        [-7.12193761e-01],
#        [ 2.83512194e-01],
#        [-3.55102775e-02],
#        [-2.29410672e-01],
#        [-9.17226688e-02],
#        [ 2.73042132e-03],
#        [ 6.48710269e-01],
#        [-4.92242937e-01],
#        [-3.47485261e-01],
#        [ 7.89128575e-01],
#        [-5.94635918e-01],
#        [ 1.12011853e-01],
#        [-2.31770553e-01],
#        [ 7.31240027e-04],
#        [ 3.56969892e-01],
#        [-7.90068353e-01],
#        [ 3.77350324e-01],
#        [-2.24470800e-01],
#        [ 7.95343593e-01],
#        [-1.02500940e+00],
#        [-3.55727805e-03],
#        [ 3.86784615e-01],
#        [-6.09420073e-02],
#        [ 1.43977132e-02],
#        [-9.55974227e-01],
#        [ 6.38458108e-01],
#        [-8.75500634e-02],
#        [-2.90538008e-01],
#        [ 4.57912594e-01],
#        [-6.73107209e-02],
#        [ 1.42705461e+00],
#        [-6.76089593e-01],
#        [-5.28398206e-01],
#        [ 8.30198539e-01],
#        [-4.55470649e-02],
#        [-4.06003192e-01],
#        [-6.67797977e-01],
#        [ 7.03429506e-01],
#        [-4.40771996e-01],
#        [-5.28646483e-01],
#        [ 4.39797818e-01],
#        [-1.47644276e+00],
#        [ 2.05114006e+00],
#        [-1.39181868e+00],
#        [ 6.22053170e-02],
#        [ 1.75505421e+00],
#        [-1.70712597e+00],
#        [-4.57176500e-01],
#        [ 2.64781710e-01],
#        [ 6.09055187e-01],
#        [-3.02960352e-01],
#        [-1.07525175e-01],
#        [ 1.41711910e-01],
#        [-9.84448536e-02],
#        [ 1.12131747e+00],
#        [-9.49464424e-01],
#        [-4.52648678e-01],
#        [ 2.43824955e-01],
#        [ 4.42121868e-02],
#        [-8.64769931e-01],
#        [ 8.59713385e-01],
#        [-3.29668368e-01],
#        [-6.30018186e-01],
#        [-5.04283577e-02],
#        [-4.24470193e-01],
#        [-3.24758907e-01],
#        [ 1.44313008e+00],
#        [-8.00553336e-01],
#        [-2.63519148e-01],
#        [ 8.52081099e-01],
#        [-7.48879236e-01],
#        [-7.38157193e-01],
#        [ 5.80000751e-01],
#        [-7.55855432e-01],
#        [ 5.91618188e-01],
#        [-8.30860626e-01],
#        [ 7.67029147e-01],
#        [ 2.22841778e-01],
#        [ 8.81889092e-01],
#        [-6.18012130e-01],
#        [-7.65195746e-01],
#        [ 1.27241669e+00],
#        [ 3.64544346e-01],
#        [-4.81355874e-01],
#        [-6.95618005e-01],
#        [ 6.03692545e-01],
#        [-7.01855351e-01],
#        [-1.03235118e+00],
#        [ 1.56520228e+00],
#        [-2.55537628e-01],
#        [ 7.71764115e-01],
#        [-7.52835471e-01],
#        [-5.90308199e-02],
#        [ 5.32350439e-01],
#        [ 2.72075232e-01],
#        [-4.68359700e-01],
#        [-7.99960063e-01],
#        [ 9.78946602e-01],
#        [-5.15364142e-01],
#        [ 1.06191138e+00],
#        [-7.44967870e-01],
#        [-5.64630435e-02]])

# %%
y_train, type(y_train)
# Out:
# (array([ 1.28320202e-02,  5.38373409e-01, -5.28216235e-01, -1.21821565e-01,
#         -3.85043944e-01,  1.76911211e-01,  2.85687363e-01, -1.70816214e-01,
#         -6.65885727e-02, -1.68264142e-01,  4.59219291e-01, -1.69118607e+00,
#          1.97437219e-01,  6.17773312e-01, -1.41594016e-01, -4.62411264e-01,
#          4.11412684e-01,  2.79929621e-01, -3.16689643e-01, -4.66776558e-01,
#          8.61931679e-01, -4.30920419e-01,  2.62087551e-01, -6.29943653e-01,
#         -4.87618148e-01,  6.78559641e-01, -2.57178353e-01, -1.50888215e-01,
#         -3.94478734e-01,  2.91457568e-01,  2.93432136e-02, -7.47747530e-01,
#          5.76109576e-01,  5.38827901e-02, -2.58784927e-01, -2.06315433e-01,
#         -2.92398842e-01,  3.66876558e-01,  3.78646863e-01, -5.22681656e-01,
#         -8.58761668e-01,  9.02090609e-02, -1.25223164e-01,  1.79954917e-02,
#          8.02302731e-01, -1.07625340e+00,  6.28196724e-01,  1.37664191e-01,
#         -6.49517433e-01,  5.93133527e-01, -6.59248361e-01, -5.98483220e-01,
#          4.16192337e-02,  3.86099359e-01,  5.58858536e-01, -3.87951731e-01,
#          9.25305541e-02,  2.94521152e-01,  4.94869529e-01, -7.27941676e-01,
#         -3.36445143e-01,  7.53107666e-01, -2.01530319e-01, -1.02121808e+00,
#          3.17639116e-01,  2.31550929e-01, -8.71557112e-02, -4.55935362e-01,
#         -1.71441394e-01, -2.34071357e-01,  1.33145037e+00, -8.03994820e-01,
#         -3.23366459e-01,  7.51823653e-01, -2.98491110e-01, -7.82606008e-02,
#         -7.12193761e-01,  2.83512194e-01, -3.55102775e-02, -2.29410672e-01,
#         -9.17226688e-02,  2.73042132e-03,  6.48710269e-01, -4.92242937e-01,
#         -3.47485261e-01,  7.89128575e-01, -5.94635918e-01,  1.12011853e-01,
#         -2.31770553e-01,  7.31240027e-04,  3.56969892e-01, -7.90068353e-01,
#          3.77350324e-01, -2.24470800e-01,  7.95343593e-01, -1.02500940e+00,
#         -3.55727805e-03,  3.86784615e-01, -6.09420073e-02,  1.43977132e-02,
#         -9.55974227e-01,  6.38458108e-01, -8.75500634e-02, -2.90538008e-01,
#          4.57912594e-01, -6.73107209e-02,  1.42705461e+00, -6.76089593e-01,
#         -5.28398206e-01,  8.30198539e-01, -4.55470649e-02, -4.06003192e-01,
#         -6.67797977e-01,  7.03429506e-01, -4.40771996e-01, -5.28646483e-01,
#          4.39797818e-01, -1.47644276e+00,  2.05114006e+00, -1.39181868e+00,
#          6.22053170e-02,  1.75505421e+00, -1.70712597e+00, -4.57176500e-01,
#          2.64781710e-01,  6.09055187e-01, -3.02960352e-01, -1.07525175e-01,
#          1.41711910e-01, -9.84448536e-02,  1.12131747e+00, -9.49464424e-01,
#         -4.52648678e-01,  2.43824955e-01,  4.42121868e-02, -8.64769931e-01,
#          8.59713385e-01, -3.29668368e-01, -6.30018186e-01, -5.04283577e-02,
#         -4.24470193e-01, -3.24758907e-01,  1.44313008e+00, -8.00553336e-01,
#         -2.63519148e-01,  8.52081099e-01, -7.48879236e-01, -7.38157193e-01,
#          5.80000751e-01, -7.55855432e-01,  5.91618188e-01, -8.30860626e-01,
#          7.67029147e-01,  2.22841778e-01,  8.81889092e-01, -6.18012130e-01,
#         -7.65195746e-01,  1.27241669e+00,  3.64544346e-01, -4.81355874e-01,
#         -6.95618005e-01,  6.03692545e-01, -7.01855351e-01, -1.03235118e+00,
#          1.56520228e+00, -2.55537628e-01,  7.71764115e-01, -7.52835471e-01,
#         -5.90308199e-02,  5.32350439e-01,  2.72075232e-01, -4.68359700e-01,
#         -7.99960063e-01,  9.78946602e-01, -5.15364142e-01,  1.06191138e+00,
#         -7.44967870e-01, -5.64630435e-02,  2.93978375e+00]),
#  numpy.ndarray)

# %% [markdown]
# # Creando el modelo

# %%
(x_train.shape[0],1,1)
# Out:
# (179, 1, 1)

# %%
x_train = np.reshape(x_train,(x_train.shape[0],1,1))
x_val = np.reshape(x_val, (x_val.shape[0],1,1))
x_test = np.reshape(x_test, (x_test.shape[0],1,1))
len(x_val)
# Out:
# 59

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# /home/danidubon12/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_5 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_7 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo1.compile(loss='mean_squared_error',optimizer="rmsprop")

# %%
epocas = 50
history= modelo1.fit(
    x = x_train,
    y = y_train,
    batch_size = lote,
    epochs = epocas,
    shuffle = False,
    validation_data = (x_val,y_val),
    verbose=1
)
# Out:
# Epoch 1/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2773 - val_loss: 0.7433
# Epoch 2/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2660 - val_loss: 0.7051
# Epoch 3/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2592 - val_loss: 0.6777
# Epoch 4/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2553 - val_loss: 0.6587
# Epoch 5/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2531 - val_loss: 0.6460
# Epoch 6/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2521 - val_loss: 0.6378
# Epoch 7/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2515 - val_loss: 0.6323
# Epoch 8/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2512 - val_loss: 0.6287
# Epoch 9/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2510 - val_loss: 0.6264
# Epoch 10/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2508 - val_loss: 0.6248
# Epoch 11/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2506 - val_loss: 0.6237
# Epoch 12/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2505 - val_loss: 0.6229
# Epoch 13/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2503 - val_loss: 0.6224
# Epoch 14/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2502 - val_loss: 0.6221
# Epoch 15/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2500 - val_loss: 0.6219
# Epoch 16/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2499 - val_loss: 0.6218
# Epoch 17/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2498 - val_loss: 0.6218
# Epoch 18/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2497 - val_loss: 0.6218
# Epoch 19/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2496 - val_loss: 0.6218
# Epoch 20/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2495 - val_loss: 0.6219
# Epoch 21/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2494 - val_loss: 0.6221
# Epoch 22/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2494 - val_loss: 0.6222
# Epoch 23/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2493 - val_loss: 0.6224
# Epoch 24/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2493 - val_loss: 0.6225
# Epoch 25/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2492 - val_loss: 0.6227
# Epoch 26/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2492 - val_loss: 0.6229
# Epoch 27/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2491 - val_loss: 0.6231
# Epoch 28/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2491 - val_loss: 0.6233
# Epoch 29/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2491 - val_loss: 0.6236
# Epoch 30/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2490 - val_loss: 0.6238
# Epoch 31/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2490 - val_loss: 0.6240
# Epoch 32/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2490 - val_loss: 0.6242
# Epoch 33/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2490 - val_loss: 0.6244
# Epoch 34/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2490 - val_loss: 0.6247
# Epoch 35/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2490 - val_loss: 0.6249
# Epoch 36/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6251
# Epoch 37/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6253
# Epoch 38/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6255
# Epoch 39/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6258
# Epoch 40/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6260
# Epoch 41/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6262
# Epoch 42/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6264
# Epoch 43/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6266
# Epoch 44/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6268
# Epoch 45/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2489 - val_loss: 0.6269
# Epoch 46/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6271
# Epoch 47/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6273
# Epoch 48/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6275
# Epoch 49/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6276
# Epoch 50/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2489 - val_loss: 0.6278

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')

# %%
print("Pérdida en Train")
modelo1.evaluate(
    x = x_train,
    y = y_train
)
print("Pérdida en Validación")
modelo1.evaluate(
    x = x_val,
    y = y_val
)
print("Pérdida en Test")
modelo1.evaluate(
    x = x_test,
    y = y_test
)
# Out:
# Pérdida en Train
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2925
# Pérdida en Validación
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5770
# Pérdida en Test
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.1941
# 2.215376615524292

# %%
prediccion_val = []

def prediccion_fun(data,modelo, batch_size,scaler,dif=False,dif_cant=1, Series = None , n=1):
    prediccion = [0]* (len(data))
    i=0
    for X in data:
        # X = np.reshape(X,(1,1,1))
        X = np.reshape(X, (1,) + X.shape)
        yhat = modelo1.predict(X, batch_size=batch_size,verbose=0)
        # invert scaling
        yhat = scaler.inverse_transform(yhat)
        if dif:
             # invert differencing
            yhat  = yhat + Series[(n+dif_cant*i)]
        # store
        prediccion[i]=yhat[0][0]
        i = i+1
    return prediccion


prediccion_val = prediccion_fun(x_val,modelo1, 1,scaler,dif=True,dif_cant=1, Series = sup_imp_h.values , n=train_end)
prediccion_test = prediccion_fun(x_test,modelo1, 1,scaler,dif=True,dif_cant=1, Series = sup_imp_h.values , n = len(sup_imp_h.values) - len(x_test))

# %%
df_val = pd.DataFrame(prediccion_val, index=sup_con_h[train_end+1:val_end].index)
df_test = pd.DataFrame(prediccion_test, index=sup_con_h[val_end:].index[:len(prediccion_test)])


plt.plot(sup_con_h, label='Serie original')
plt.plot(df_val, label='Predicción validación')
plt.plot(df_test, label='Predicción prueba')

plt.legend()
plt.title('Predicción de series temporales')
plt.xlabel('Fecha')
plt.ylabel('Gasolina Regular')
plt.grid(True)
plt.show()

# %%
unidades =  10
paso = 1 # lags, 1 lag es un mes. 
caracteristicas = 1 # es univariada
lote = 1


modelo1 = Sequential()
modelo1.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False  # desactivamos estado entre batches
))

modelo1.add(Dense(1))
modelo1.summary()
# Out:
# /home/danidubon12/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Supón que ya tienes sup_imp_h_diff_scaled definido y escalado
total_len = len(sup_con_h_diff_scaled)

# Definir proporciones
train_prop = 0.6
val_prop = 0.2
test_prop = 0.2 

# Calcular índices
train_end = int(train_prop * total_len)
val_end = train_end + int(val_prop * total_len)

# Separar sin solapamientos
train = sup_con_h_diff_scaled[:train_end]
validation = sup_con_h_diff_scaled[train_end:val_end]
test = sup_con_h_diff_scaled[val_end:]

# Redimensionar para LSTM univariante
train = train.reshape(-1, 1)
validation = validation.reshape(-1, 1)
test = test.reshape(-1, 1)

# %%
# Segundo Modelo
unidades =  32  # Aumentamos el número de unidades
paso = 6       # Aumentamos los lags a 6 (en el primero era 1)
caracteristicas = 1 # es univariada
lote = 1
epocas = 150   # Aumentamos el número de épocas

# %%
def supervisada(serie, retrasos=6):  # Ahora 6 lags
    serie_x = []
    serie_y = []
    for i in range(len(serie)-retrasos):
        valor = serie[i:(i+retrasos),0]
        valor_sig = serie[i+retrasos,0]
        serie_x.append(valor)
        serie_y.append(valor_sig)
    return np.array(serie_x), np.array(serie_y)

x_train2, y_train2 = supervisada(train, retrasos=6)
x_val2, y_val2 = supervisada(validation, retrasos=6)
x_test2, y_test2 = supervisada(test, retrasos=6)

# Reshape para LSTM: (samples, time_steps, features)
x_train2 = np.reshape(x_train2, (x_train2.shape[0], 6, 1))
x_val2 = np.reshape(x_val2, (x_val2.shape[0], 6, 1))
x_test2 = np.reshape(x_test2, (x_test2.shape[0], 6, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

modelo2 = Sequential()
modelo2.add(LSTM(
    units=unidades, 
    input_shape=(paso, caracteristicas), 
    stateful=False
))
modelo2.add(Dense(1))
modelo2.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_9 (LSTM)                   │ (None, 32)             │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,385 (17.13 KB)
#  Trainable params: 4,385 (17.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
modelo2.compile(loss='mean_squared_error', optimizer="adam")

# %%
epocas = 100
history2 = modelo2.fit(
    x=x_train2,
    y=y_train2,
    batch_size=lote,
    epochs=epocas,
    shuffle=False,
    validation_data=(x_val2, y_val2),
    verbose=1
)
# Out:
# Epoch 1/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2731 - val_loss: 0.6337
# Epoch 2/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2336 - val_loss: 0.5612
# Epoch 3/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2225 - val_loss: 0.5320
# Epoch 4/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2205 - val_loss: 0.5213
# Epoch 5/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2195 - val_loss: 0.5155
# Epoch 6/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2183 - val_loss: 0.5095
# Epoch 7/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2165 - val_loss: 0.5002
# Epoch 8/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2138 - val_loss: 0.4843
# Epoch 9/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2097 - val_loss: 0.4620
# Epoch 10/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2051 - val_loss: 0.4404
# Epoch 11/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2019 - val_loss: 0.4233
# Epoch 12/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2004 - val_loss: 0.4111
# Epoch 13/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1994 - val_loss: 0.4028
# Epoch 14/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1987 - val_loss: 0.3972
# Epoch 15/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1979 - val_loss: 0.3935
# Epoch 16/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1973 - val_loss: 0.3911
# Epoch 17/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1967 - val_loss: 0.3898
# Epoch 18/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1962 - val_loss: 0.3892
# Epoch 19/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1957 - val_loss: 0.3892
# Epoch 20/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1953 - val_loss: 0.3897
# Epoch 21/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1949 - val_loss: 0.3906
# Epoch 22/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1945 - val_loss: 0.3918
# Epoch 23/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1941 - val_loss: 0.3933
# Epoch 24/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1936 - val_loss: 0.3951
# Epoch 25/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1932 - val_loss: 0.3973
# Epoch 26/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1927 - val_loss: 0.3997
# Epoch 27/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1922 - val_loss: 0.4025
# Epoch 28/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1916 - val_loss: 0.4056
# Epoch 29/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1911 - val_loss: 0.4091
# Epoch 30/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1904 - val_loss: 0.4130
# Epoch 31/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1898 - val_loss: 0.4173
# Epoch 32/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1891 - val_loss: 0.4218
# Epoch 33/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1884 - val_loss: 0.4267
# Epoch 34/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1876 - val_loss: 0.4318
# Epoch 35/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1869 - val_loss: 0.4370
# Epoch 36/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1863 - val_loss: 0.4421
# Epoch 37/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1857 - val_loss: 0.4470
# Epoch 38/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1852 - val_loss: 0.4516
# Epoch 39/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1848 - val_loss: 0.4556
# Epoch 40/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1845 - val_loss: 0.4592
# Epoch 41/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1843 - val_loss: 0.4621
# Epoch 42/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1841 - val_loss: 0.4646
# Epoch 43/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1840 - val_loss: 0.4667
# Epoch 44/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1839 - val_loss: 0.4684
# Epoch 45/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1838 - val_loss: 0.4698
# Epoch 46/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1837 - val_loss: 0.4710
# Epoch 47/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1837 - val_loss: 0.4720
# Epoch 48/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1836 - val_loss: 0.4729
# Epoch 49/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1835 - val_loss: 0.4737
# Epoch 50/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1834 - val_loss: 0.4744
# Epoch 51/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1834 - val_loss: 0.4750
# Epoch 52/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1833 - val_loss: 0.4757
# Epoch 53/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1832 - val_loss: 0.4763
# Epoch 54/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1832 - val_loss: 0.4769
# Epoch 55/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1831 - val_loss: 0.4775
# Epoch 56/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1830 - val_loss: 0.4782
# Epoch 57/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1830 - val_loss: 0.4788
# Epoch 58/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1830 - val_loss: 0.4795
# Epoch 59/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1829 - val_loss: 0.4802
# Epoch 60/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1829 - val_loss: 0.4810
# Epoch 61/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1828 - val_loss: 0.4817
# Epoch 62/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1828 - val_loss: 0.4825
# Epoch 63/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1827 - val_loss: 0.4833
# Epoch 64/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1826 - val_loss: 0.4842
# Epoch 65/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1824 - val_loss: 0.4851
# Epoch 66/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1823 - val_loss: 0.4861
# Epoch 67/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1821 - val_loss: 0.4871
# Epoch 68/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1818 - val_loss: 0.4882
# Epoch 69/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1815 - val_loss: 0.4894
# Epoch 70/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1812 - val_loss: 0.4906
# Epoch 71/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1808 - val_loss: 0.4918
# Epoch 72/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1804 - val_loss: 0.4931
# Epoch 73/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1799 - val_loss: 0.4944
# Epoch 74/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1794 - val_loss: 0.4957
# Epoch 75/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1789 - val_loss: 0.4971
# Epoch 76/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1783 - val_loss: 0.4985
# Epoch 77/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1776 - val_loss: 0.4998
# Epoch 78/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1769 - val_loss: 0.5012
# Epoch 79/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1762 - val_loss: 0.5025
# Epoch 80/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1754 - val_loss: 0.5039
# Epoch 81/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1746 - val_loss: 0.5052
# Epoch 82/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1737 - val_loss: 0.5065
# Epoch 83/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1728 - val_loss: 0.5079
# Epoch 84/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1718 - val_loss: 0.5092
# Epoch 85/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1708 - val_loss: 0.5106
# Epoch 86/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1696 - val_loss: 0.5120
# Epoch 87/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1685 - val_loss: 0.5135
# Epoch 88/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1673 - val_loss: 0.5151
# Epoch 89/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1660 - val_loss: 0.5168
# Epoch 90/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1646 - val_loss: 0.5186
# Epoch 91/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1632 - val_loss: 0.5205
# Epoch 92/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1617 - val_loss: 0.5226
# Epoch 93/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1602 - val_loss: 0.5248
# Epoch 94/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1586 - val_loss: 0.5271
# Epoch 95/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1570 - val_loss: 0.5296
# Epoch 96/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1553 - val_loss: 0.5322
# Epoch 97/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1535 - val_loss: 0.5350
# Epoch 98/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1517 - val_loss: 0.5379
# Epoch 99/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1499 - val_loss: 0.5408
# Epoch 100/100
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1481 - val_loss: 0.5440

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss (Modelo 2)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='center')
plt.show()

# %%
print("Pérdida en Train (Modelo 2)")
modelo2.evaluate(x_train2, y_train2)
print("Pérdida en Validación (Modelo 2)")
modelo2.evaluate(x_val2, y_val2)
print("Pérdida en Test (Modelo 2)")
modelo2.evaluate(x_test2, y_test2)
# Out:
# Pérdida en Train (Modelo 2)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1337
# Pérdida en Validación (Modelo 2)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5177
# Pérdida en Test (Modelo 2)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.4330
# 2.5540127754211426

# %%
def prediccion_fun(data, modelo, batch_size, scaler, dif=False, dif_cant=1, Series=None, n=1):
    prediccion = [0] * (len(data))
    i = 0
    for X in data:
        X = np.reshape(X, (1,) + X.shape)
        yhat = modelo.predict(X, batch_size=batch_size, verbose=0)
        yhat = scaler.inverse_transform(yhat)
        if dif:
            yhat = yhat + Series[(n + dif_cant * i)]
        prediccion[i] = yhat[0][0]
        i = i + 1
    return prediccion

prediccion_val2 = prediccion_fun(x_val2, modelo2, 1, scaler, dif=True, dif_cant=1, Series=sup_imp_h.values, n=train_end)
prediccion_test2 = prediccion_fun(x_test2, modelo2, 1, scaler, dif=True, dif_cant=1, Series=sup_imp_h.values, n=len(sup_imp_h.values) - len(x_test2))

# %%
df_val2 = pd.DataFrame(prediccion_val2, index=sup_con_h[train_end+paso:val_end].index)
df_test2 = pd.DataFrame(prediccion_test2, index=sup_con_h[val_end:].index[:len(prediccion_test2)])

plt.plot(sup_imp_h, label='Serie original')
plt.plot(df_val2, label='Predicción validación (Modelo 2)')
plt.plot(df_test2, label='Predicción prueba (Modelo 2)')

plt.legend()
plt.title('Predicción de series temporales - Modelo 2')
plt.xlabel('Fecha')
plt.ylabel('Gasolina Regular')
plt.grid(True)
plt.show()
